# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# malaria_2003_df = pd.read_csv('malaria_notification_data_csv/NOTIPO03.csv')
# malaria_2004_df = pd.read_csv('malaria_notification_data_csv/NOTIPO04.csv')
# malaria_2005_df = pd.read_csv('malaria_notification_data_csv/NOTIPO05.csv')
# malaria_2006_df = pd.read_csv('malaria_notification_data_csv/NOTIPO06.csv')
# malaria_2007_df = pd.read_csv('malaria_notification_data_csv/NOTIPO07.csv')
# malaria_2008_df = pd.read_csv('malaria_notification_data_csv/NOTIPO08.csv')
# malaria_2009_df = pd.read_csv('malaria_notification_data_csv/NOTIPO09.csv')
# malaria_2010_df = pd.read_csv('malaria_notification_data_csv/NOTIPO10.csv')
# malaria_2011_df = pd.read_csv('malaria_notification_data_csv/NOTIPO11.csv')
# malaria_2012_df = pd.read_csv('malaria_notification_data_csv/NOTIPO12.csv')
# malaria_2013_df = pd.read_csv('malaria_notification_data_csv/NOTIPO13.csv')
# malaria_2014_df = pd.read_csv('malaria_notification_data_csv/NOTIPO14.csv')
# malaria_2015_df = pd.read_csv('malaria_notification_data_csv/NOTIPO15.csv')
# malaria_2016_df = pd.read_csv('malaria_notification_data_csv/NOTIPO16.csv')
malaria_2017_df = pd.read_csv('malaria_notification_data_csv/NOTIPO17.csv')
malaria_2018_df = pd.read_csv('malaria_notification_data_csv/NOTIPO18.csv')
malaria_2019_df = pd.read_csv('malaria_notification_data_csv/NOTIPO19.csv')
malaria_2020_df = pd.read_csv('malaria_notification_data_csv/NOTIPO20.csv')
malaria_2021_df = pd.read_csv('malaria_notification_data_csv/NOTIPO21.csv')
# malaria_2022_df = pd.read_csv('malaria_notification_data_csv/NOTIPO22.csv')
# malaria_2023_df = pd.read_csv('malaria_notification_data_csv/NOTIPO23.csv')
# Out:
# C:\Users\ilana\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (41) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# C:\Users\ilana\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (37,38,41) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# C:\Users\ilana\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (29,30,41) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# C:\Users\ilana\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (30) have mixed types.Specify dtype option on import or set low_memory=False.
# ...

# %%
malaria_2017_2021_df = pd.concat([malaria_2017_df, malaria_2018_df, malaria_2019_df, malaria_2020_df, malaria_2021_df])

malaria_2017_2021_df = malaria_2017_2021_df.reset_index().drop(columns=['index'])
malaria_2017_2021_df
# Out:
#          COD_NOTI  DT_NOTIF    DT_ENVLO  DT_DIGIT SEM_NOTI  TIPO_LAM  \
# 0            2990  10/09/17  13/09/2017  13/09/17  37/2017         1
# 1             421  31/01/17  03/02/2017  03/02/17  05/2017         1
# 2            2991  10/09/17  13/09/2017  13/09/17  37/2017         1
# 3            5196  09/12/17  14/12/2017  14/12/17  49/2017         1
# 4            7891  24/08/17  25/08/2017  25/08/17  34/2017         1
# ...           ...       ...         ...       ...      ...       ...
# 1006355       139  19/07/21  20/07/2021  20/07/21  29/2021         1
# 1006356      3156  07/07/21  14/07/2021  14/07/21  27/2021         1
# 1006357       697  16/08/21  25/08/2021  25/08/21  33/2021         1
# 1006358      4779  21/07/21  22/07/2021  22/07/21  29/2021         1
# 1006359       571  09/07/21  30/07/2021  12/07/21  27/2021         1
#
#          UF_NOTIF  MUN_NOTI  COD_UNIN  COD_AGEN  ... NU_HEMOGLOBINA_TOTAL  \
# ...

# %% [markdown]
# #### Gets vivax cases (RES_EXAM = 4)

# %%
vivax_cases_df = malaria_2017_2021_df[malaria_2017_2021_df.get('RES_EXAM')==4]
vivax_cases_df
# Out:
#          COD_NOTI  DT_NOTIF    DT_ENVLO  DT_DIGIT SEM_NOTI  TIPO_LAM  \
# 0            2990  10/09/17  13/09/2017  13/09/17  37/2017         1
# 1             421  31/01/17  03/02/2017  03/02/17  05/2017         1
# 2            2991  10/09/17  13/09/2017  13/09/17  37/2017         1
# 3            5196  09/12/17  14/12/2017  14/12/17  49/2017         1
# 4            7891  24/08/17  25/08/2017  25/08/17  34/2017         1
# ...           ...       ...         ...       ...      ...       ...
# 1006354      1639  10/09/21  05/01/2022  05/01/22  36/2021         2
# 1006355       139  19/07/21  20/07/2021  20/07/21  29/2021         1
# 1006357       697  16/08/21  25/08/2021  25/08/21  33/2021         1
# 1006358      4779  21/07/21  22/07/2021  22/07/21  29/2021         1
# 1006359       571  09/07/21  30/07/2021  12/07/21  27/2021         1
#
#          UF_NOTIF  MUN_NOTI  COD_UNIN  COD_AGEN  ... NU_HEMOGLOBINA_TOTAL  \
# ...

# %%
len(vivax_cases_df)/len(malaria_2017_2021_df)*100
# Out:
# 87.89419293294645

# %% [markdown]
# About 88% of all malaria cases between 2017 and 2021 were caused by P. Vivax

# %% [markdown]
# #### Gets name of UFs

# %%
uf_dict = {11 : 'RO',
           12 : 'AC',
           13 : 'AM',
           14 : 'RR',
           15 : 'PA',
           16 : 'AP',
           17 : 'TO',
           21 : 'MA',
           22 : 'PI',
           23 : 'CE',
           24 : 'RN',
           25 : 'PB',
           26 : 'PE',
           27 : 'AL',
           28 : 'SE',
           29 : 'BA',
           31 : 'MG', 
           32 : 'ES',
           33 : 'RJ',
           35 : 'SP',
           41 : 'PR',
           42 : 'SC',
           43 : 'RS',
           50 : 'MS',
           51 : 'MT',
           52 : 'GO',
           53 : 'DF'
          }
corrected_ufs_df = vivax_cases_df.replace({"UF_NOTIF": uf_dict, "UF_RESID": uf_dict})
corrected_ufs_df
# Out:
#          COD_NOTI  DT_NOTIF    DT_ENVLO  DT_DIGIT SEM_NOTI  TIPO_LAM UF_NOTIF  \
# 0            2990  10/09/17  13/09/2017  13/09/17  37/2017         1       AM
# 1             421  31/01/17  03/02/2017  03/02/17  05/2017         1       AM
# 2            2991  10/09/17  13/09/2017  13/09/17  37/2017         1       AM
# 3            5196  09/12/17  14/12/2017  14/12/17  49/2017         1       AM
# 4            7891  24/08/17  25/08/2017  25/08/17  34/2017         1       AM
# ...           ...       ...         ...       ...      ...       ...      ...
# 1006354      1639  10/09/21  05/01/2022  05/01/22  36/2021         2       RR
# 1006355       139  19/07/21  20/07/2021  20/07/21  29/2021         1       AP
# 1006357       697  16/08/21  25/08/2021  25/08/21  33/2021         1       AM
# 1006358      4779  21/07/21  22/07/2021  22/07/21  29/2021         1       AM
# 1006359       571  09/07/21  30/07/2021  12/07/21  27/2021         1       AM
#
# ...

# %% [markdown]
# #### Gets data for the Amazon region

# %%
amazon_df = corrected_ufs_df[corrected_ufs_df.get('UF_NOTIF').isin(['RO', 'AC', 'AM', 'RR', 'PA', 'AP', 'TO'])]
amazon_df
# Out:
#          COD_NOTI  DT_NOTIF    DT_ENVLO  DT_DIGIT SEM_NOTI  TIPO_LAM UF_NOTIF  \
# 0            2990  10/09/17  13/09/2017  13/09/17  37/2017         1       AM
# 1             421  31/01/17  03/02/2017  03/02/17  05/2017         1       AM
# 2            2991  10/09/17  13/09/2017  13/09/17  37/2017         1       AM
# 3            5196  09/12/17  14/12/2017  14/12/17  49/2017         1       AM
# 4            7891  24/08/17  25/08/2017  25/08/17  34/2017         1       AM
# ...           ...       ...         ...       ...      ...       ...      ...
# 1006354      1639  10/09/21  05/01/2022  05/01/22  36/2021         2       RR
# 1006355       139  19/07/21  20/07/2021  20/07/21  29/2021         1       AP
# 1006357       697  16/08/21  25/08/2021  25/08/21  33/2021         1       AM
# 1006358      4779  21/07/21  22/07/2021  22/07/21  29/2021         1       AM
# 1006359       571  09/07/21  30/07/2021  12/07/21  27/2021         1       AM
#
# ...

# %%
amazonas_df = amazon_df[amazon_df.get('UF_NOTIF')=='AM']
amazonas_df
# Out:
#          COD_NOTI  DT_NOTIF    DT_ENVLO  DT_DIGIT SEM_NOTI  TIPO_LAM UF_NOTIF  \
# 0            2990  10/09/17  13/09/2017  13/09/17  37/2017         1       AM
# 1             421  31/01/17  03/02/2017  03/02/17  05/2017         1       AM
# 2            2991  10/09/17  13/09/2017  13/09/17  37/2017         1       AM
# 3            5196  09/12/17  14/12/2017  14/12/17  49/2017         1       AM
# 4            7891  24/08/17  25/08/2017  25/08/17  34/2017         1       AM
# ...           ...       ...         ...       ...      ...       ...      ...
# 1006350        39  03/05/21  25/02/2022  13/08/21  18/2021         1       AM
# 1006353      1350  29/11/21  09/12/2021  09/12/21  48/2021         1       AM
# 1006357       697  16/08/21  25/08/2021  25/08/21  33/2021         1       AM
# 1006358      4779  21/07/21  22/07/2021  22/07/21  29/2021         1       AM
# 1006359       571  09/07/21  30/07/2021  12/07/21  27/2021         1       AM
#
# ...

# %%
len(amazonas_df)/len(vivax_cases_df)*100
# Out:
# 37.89642432382322

# %% [markdown]
# Around 37.9% of all malaria cases caused by P. Vivax between 2017 and 2021 were notified in the state of Amazonas

# %% [markdown]
# #### Cases notified of Amazonas' residents in the state

# %%
amazonas_notif_and_resid = amazon_df[(amazon_df.get('UF_NOTIF')=='AM') & (amazon_df.get('UF_RESID')=='AM')]
amazonas_notif_and_resid
# Out:
#          COD_NOTI  DT_NOTIF    DT_ENVLO  DT_DIGIT SEM_NOTI  TIPO_LAM UF_NOTIF  \
# 0            2990  10/09/17  13/09/2017  13/09/17  37/2017         1       AM
# 1             421  31/01/17  03/02/2017  03/02/17  05/2017         1       AM
# 2            2991  10/09/17  13/09/2017  13/09/17  37/2017         1       AM
# 3            5196  09/12/17  14/12/2017  14/12/17  49/2017         1       AM
# 4            7891  24/08/17  25/08/2017  25/08/17  34/2017         1       AM
# ...           ...       ...         ...       ...      ...       ...      ...
# 1006338       258  20/09/21  04/10/2021  30/09/21  38/2021         2       AM
# 1006350        39  03/05/21  25/02/2022  13/08/21  18/2021         1       AM
# 1006357       697  16/08/21  25/08/2021  25/08/21  33/2021         1       AM
# 1006358      4779  21/07/21  22/07/2021  22/07/21  29/2021         1       AM
# 1006359       571  09/07/21  30/07/2021  12/07/21  27/2021         1       AM
#
# ...

# %%
len(amazonas_notif_and_resid)/len(amazonas_df)*100
# Out:
# 99.53580783160206

# %% [markdown]
# From all cases notified in the state of Amazonas, about 99.5% of the infected were residents of the state.

# %% [markdown]
# #### Cases registered on Amazonas based on municipality of residence

# %%
cases_by_AM_municipality = amazonas_notif_and_resid[['MUN_RESI']].groupby(['MUN_RESI']).size().reset_index(name='TOTAL_CASES').sort_values(by='TOTAL_CASES', ascending=False)
cases_by_AM_municipality['MUN_RESI'] = cases_by_AM_municipality['MUN_RESI'].astype(int)
cases_by_AM_municipality
# Out:
#     MUN_RESI  TOTAL_CASES
# 37    130260        51965
# 51    130380        47145
# 7     130040        35446
# 49    130360        17129
# 19    130120        16392
# ..       ...          ...
# 1     130006           28
# 2     130008           23
# 58    130423           17
# 3     130010           13
# 61    130440           13
#
# [62 rows x 2 columns]

# %% [markdown]
# It is possible to see that Manaus is the city of residence of most notified cases in the state of Amazonas

# %% [markdown]
# #### Cases notified of Manaus' residents in the city

# %%
manaus_notif_and_resid = corrected_ufs_df[(corrected_ufs_df.get('MUN_NOTI')==130260) & (corrected_ufs_df.get('MUN_RESI')==130260)]
manaus_notif_and_resid
# Out:
#          COD_NOTI  DT_NOTIF    DT_ENVLO  DT_DIGIT SEM_NOTI  TIPO_LAM UF_NOTIF  \
# 0            2990  10/09/17  13/09/2017  13/09/17  37/2017         1       AM
# 1             421  31/01/17  03/02/2017  03/02/17  05/2017         1       AM
# 2            2991  10/09/17  13/09/2017  13/09/17  37/2017         1       AM
# 3            5196  09/12/17  14/12/2017  14/12/17  49/2017         1       AM
# 4            7891  24/08/17  25/08/2017  25/08/17  34/2017         1       AM
# ...           ...       ...         ...       ...      ...       ...      ...
# 1005991      2653  25/09/21  29/09/2021  28/09/21  38/2021         1       AM
# 1006093       181  03/11/21  04/11/2021  04/11/21  44/2021         1       AM
# 1006111    187216  08/10/21  10/10/2021  08/10/21  40/2021         1       AM
# 1006159       148  19/10/21  21/10/2021  21/10/21  42/2021         1       AM
# 1006319        67  02/08/21  03/08/2021  03/08/21  31/2021         1       AM
#
# ...

# %% [markdown]
# #### Cases notified in Manaus

# %%
manaus_notif = corrected_ufs_df[corrected_ufs_df.get('MUN_NOTI')==130260]
manaus_notif
# Out:
#          COD_NOTI  DT_NOTIF    DT_ENVLO  DT_DIGIT SEM_NOTI  TIPO_LAM UF_NOTIF  \
# 0            2990  10/09/17  13/09/2017  13/09/17  37/2017         1       AM
# 1             421  31/01/17  03/02/2017  03/02/17  05/2017         1       AM
# 2            2991  10/09/17  13/09/2017  13/09/17  37/2017         1       AM
# 3            5196  09/12/17  14/12/2017  14/12/17  49/2017         1       AM
# 4            7891  24/08/17  25/08/2017  25/08/17  34/2017         1       AM
# ...           ...       ...         ...       ...      ...       ...      ...
# 1005999    188515  27/12/21  03/01/2022  27/12/21  52/2021         1       AM
# 1006093       181  03/11/21  04/11/2021  04/11/21  44/2021         1       AM
# 1006111    187216  08/10/21  10/10/2021  08/10/21  40/2021         1       AM
# 1006159       148  19/10/21  21/10/2021  21/10/21  42/2021         1       AM
# 1006319        67  02/08/21  03/08/2021  03/08/21  31/2021         1       AM
#
# ...

# %% [markdown]
# #### Cases of residents of Manaus

# %%
manaus_resid = corrected_ufs_df[corrected_ufs_df.get('MUN_RESI')==130260]
manaus_resid
# Out:
#          COD_NOTI  DT_NOTIF    DT_ENVLO  DT_DIGIT SEM_NOTI  TIPO_LAM UF_NOTIF  \
# 0            2990  10/09/17  13/09/2017  13/09/17  37/2017         1       AM
# 1             421  31/01/17  03/02/2017  03/02/17  05/2017         1       AM
# 2            2991  10/09/17  13/09/2017  13/09/17  37/2017         1       AM
# 3            5196  09/12/17  14/12/2017  14/12/17  49/2017         1       AM
# 4            7891  24/08/17  25/08/2017  25/08/17  34/2017         1       AM
# ...           ...       ...         ...       ...      ...       ...      ...
# 1005991      2653  25/09/21  29/09/2021  28/09/21  38/2021         1       AM
# 1006093       181  03/11/21  04/11/2021  04/11/21  44/2021         1       AM
# 1006111    187216  08/10/21  10/10/2021  08/10/21  40/2021         1       AM
# 1006159       148  19/10/21  21/10/2021  21/10/21  42/2021         1       AM
# 1006319        67  02/08/21  03/08/2021  03/08/21  31/2021         1       AM
#
# ...

# %% [markdown]
# #### Year of registration of notification based on residents of Manaus

# %%
manaus_resid['YEAR_NOTIF'] = manaus_resid['DT_NOTIF'].str[-2:].astype(int)
manaus_resid['YEAR_NOTIF'] = manaus_resid['YEAR_NOTIF'].apply(lambda x: 2000 + x if x <= 23 else 1900 + x)
manaus_resid
# Out:
# <ipython-input-16-bb7fdcbcbd17>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   manaus_resid['YEAR_NOTIF'] = manaus_resid['DT_NOTIF'].str[-2:].astype(int)
# <ipython-input-16-bb7fdcbcbd17>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   manaus_resid['YEAR_NOTIF'] = manaus_resid['YEAR_NOTIF'].apply(lambda x: 2000 + x if x <= 23 else 1900 + x)
#          COD_NOTI  DT_NOTIF    DT_ENVLO  DT_DIGIT SEM_NOTI  TIPO_LAM UF_NOTIF  \
# ...

# %% [markdown]
# #### Total cases of infected residents of Manaus by year

# %%
cases_manaus_by_year = manaus_resid[['YEAR_NOTIF']].groupby(['YEAR_NOTIF']).size().reset_index(name='TOTAL_CASES').sort_values(by='TOTAL_CASES', ascending=False)
cases_manaus_by_year['YEAR_NOTIF'] = cases_manaus_by_year['YEAR_NOTIF'].astype(int)
cases_manaus_by_year
# Out:
#    YEAR_NOTIF  TOTAL_CASES
# 0        2017        16042
# 1        2018        12618
# 2        2019         9720
# 3        2020         7501
# 4        2021         6198

# %% [markdown]
# #### Gets population data for all brazillian municipalities from 2003 to 2023

# %%
pop_df = pd.read_csv('pop_data/pop_2003-2023.csv')
pop_df = pop_df.drop(columns=['Unnamed: 0'])
pop_df
# Out:
#         MUNIC_RES   ANO  POPULACAO
# 0          110001  2003      27563
# 1          110002  2003      79680
# 2          110003  2003       7478
# 3          110004  2003      74758
# 4          110005  2003      17794
# ...           ...   ...        ...
# 105771    5222005  2021      14088
# 105772    5222054  2021       9002
# 105773    5222203  2021       6451
# 105774    5222302  2021       5941
# 105775    5300108  2021    3094325
#
# [105776 rows x 3 columns]

# %%
full_pop_df = pop_df.rename(columns={'ANO': 'YEAR', 'POPULACAO': 'POPULATION'})
full_pop_df = full_pop_df[full_pop_df.get('YEAR') >= 2017]
full_pop_df
# Out:
#         MUNIC_RES  YEAR  POPULATION
# 77926     1100015  2017       25437
# 77927     1100023  2017      107345
# 77928     1100031  2017        6224
# 77929     1100049  2017       88507
# 77930     1100056  2017       17934
# ...           ...   ...         ...
# 105771    5222005  2021       14088
# 105772    5222054  2021        9002
# 105773    5222203  2021        6451
# 105774    5222302  2021        5941
# 105775    5300108  2021     3094325
#
# [27850 rows x 3 columns]

# %% [markdown]
# #### Total cases by municipality of residence

# %%
tot_cases_brazil = corrected_ufs_df[['MUN_RESI']].groupby(['MUN_RESI']).size().reset_index(name='TOTAL_CASES').sort_values(by='TOTAL_CASES', ascending=False)
tot_cases_brazil['MUN_RESI'] = tot_cases_brazil['MUN_RESI'].astype(int)
tot_cases_brazil['MUN_RESI'] = tot_cases_brazil['MUN_RESI'].astype(str)
tot_cases_brazil
# Out:
#     MUN_RESI  TOTAL_CASES
# 111   130260        52079
# 57    120020        48668
# 125   130380        47146
# 81    130040        35567
# 16    110020        30664
# ..       ...          ...
# 565   351907            1
# 566   351930            1
# 567   352690            1
# 568   352730            1
# 738   539904            1
#
# [739 rows x 2 columns]

# %% [markdown]
# Adding an year column for date of notification

# %%
corrected_ufs_df['YEAR_NOTIF'] = corrected_ufs_df['DT_NOTIF'].str[-2:].astype(int)
corrected_ufs_df['YEAR_NOTIF'] = corrected_ufs_df['YEAR_NOTIF'].apply(lambda x: 2000 + x if x <= 23 else 1900 + x)
corrected_ufs_df
# Out:
#          COD_NOTI  DT_NOTIF    DT_ENVLO  DT_DIGIT SEM_NOTI  TIPO_LAM UF_NOTIF  \
# 0            2990  10/09/17  13/09/2017  13/09/17  37/2017         1       AM
# 1             421  31/01/17  03/02/2017  03/02/17  05/2017         1       AM
# 2            2991  10/09/17  13/09/2017  13/09/17  37/2017         1       AM
# 3            5196  09/12/17  14/12/2017  14/12/17  49/2017         1       AM
# 4            7891  24/08/17  25/08/2017  25/08/17  34/2017         1       AM
# ...           ...       ...         ...       ...      ...       ...      ...
# 1006354      1639  10/09/21  05/01/2022  05/01/22  36/2021         2       RR
# 1006355       139  19/07/21  20/07/2021  20/07/21  29/2021         1       AP
# 1006357       697  16/08/21  25/08/2021  25/08/21  33/2021         1       AM
# 1006358      4779  21/07/21  22/07/2021  22/07/21  29/2021         1       AM
# 1006359       571  09/07/21  30/07/2021  12/07/21  27/2021         1       AM
#
# ...

# %%
corrected_ufs_dfs_manaus = corrected_ufs_df[corrected_ufs_df.get('MUN_RESI')== 130260]
corrected_ufs_dfs_manaus
# Out:
#          COD_NOTI  DT_NOTIF    DT_ENVLO  DT_DIGIT SEM_NOTI  TIPO_LAM UF_NOTIF  \
# 0            2990  10/09/17  13/09/2017  13/09/17  37/2017         1       AM
# 1             421  31/01/17  03/02/2017  03/02/17  05/2017         1       AM
# 2            2991  10/09/17  13/09/2017  13/09/17  37/2017         1       AM
# 3            5196  09/12/17  14/12/2017  14/12/17  49/2017         1       AM
# 4            7891  24/08/17  25/08/2017  25/08/17  34/2017         1       AM
# ...           ...       ...         ...       ...      ...       ...      ...
# 1005991      2653  25/09/21  29/09/2021  28/09/21  38/2021         1       AM
# 1006093       181  03/11/21  04/11/2021  04/11/21  44/2021         1       AM
# 1006111    187216  08/10/21  10/10/2021  08/10/21  40/2021         1       AM
# 1006159       148  19/10/21  21/10/2021  21/10/21  42/2021         1       AM
# 1006319        67  02/08/21  03/08/2021  03/08/21  31/2021         1       AM
#
# ...

# %% [markdown]
# Getting cases in Manaus by year

# %%
tot_cases_manaus_by_year = corrected_ufs_df.groupby(['MUN_RESI', 'YEAR_NOTIF']).size().reset_index(name='TOTAL_CASES').sort_values(by='TOTAL_CASES', ascending=False)
tot_cases_manaus_by_year = tot_cases_manaus_by_year.sort_values(by=['YEAR_NOTIF', 'MUN_RESI'], ascending = True)
tot_cases_manaus_by_year['MUN_RESI'] = tot_cases_manaus_by_year['MUN_RESI'].astype(int)
tot_cases_manaus_by_year['MUN_RESI'] = tot_cases_manaus_by_year['MUN_RESI'].astype(str)
tot_cases_manaus_by_year = tot_cases_manaus_by_year[tot_cases_manaus_by_year.get('MUN_RESI') == '130260']
tot_cases_manaus_by_year
# Out:
#     MUN_RESI  YEAR_NOTIF  TOTAL_CASES
# 531   130260        2017        16042
# 532   130260        2018        12618
# 533   130260        2019         9720
# 534   130260        2020         7501
# 535   130260        2021         6198

# %%
full_pop_df['MUNIC_RES'] = full_pop_df['MUNIC_RES'].astype(str)
full_pop_df
# Out:
#        MUNIC_RES  YEAR  POPULATION
# 77926    1100015  2017       25437
# 77927    1100023  2017      107345
# 77928    1100031  2017        6224
# 77929    1100049  2017       88507
# 77930    1100056  2017       17934
# ...          ...   ...         ...
# 105771   5222005  2021       14088
# 105772   5222054  2021        9002
# 105773   5222203  2021        6451
# 105774   5222302  2021        5941
# 105775   5300108  2021     3094325
#
# [27850 rows x 3 columns]

# %% [markdown]
# Corrects IBGE code to limit to 6 digits

# %%
for i in np.arange(0, len(full_pop_df['MUNIC_RES'])):
    if len(full_pop_df['MUNIC_RES'].iloc[i]) > 6:
        full_pop_df['MUNIC_RES'].iloc[i] = full_pop_df['MUNIC_RES'].iloc[i][:-1]
    
full_pop_df
# Out:
# C:\Users\ilana\anaconda3\lib\site-packages\pandas\core\indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
#        MUNIC_RES  YEAR  POPULATION
# 77926     110001  2017       25437
# 77927     110002  2017      107345
# 77928     110003  2017        6224
# 77929     110004  2017       88507
# 77930     110005  2017       17934
# ...          ...   ...         ...
# 105771    522200  2021       14088
# 105772    522205  2021        9002
# 105773    522220  2021        6451
# 105774    522230  2021        5941
# 105775    530010  2021     3094325
#
# [27850 rows x 3 columns]

# %%
full_pop_manaus_df = full_pop_df
full_pop_manaus_df['MUNIC_RES'] = full_pop_manaus_df['MUNIC_RES'].astype(str)
full_pop_manaus_df = full_pop_manaus_df[full_pop_manaus_df.get('MUNIC_RES') == '130260']
full_pop_manaus_df
# Out:
#        MUNIC_RES  YEAR  POPULATION
# 78037     130260  2017     2130264
# 83607     130260  2018     2145444
# 89177     130260  2019     2182763
# 94747     130260  2020     2219580
# 100317    130260  2021     2255903

# %%
tot_cases_manaus_by_year = tot_cases_manaus_by_year.rename(columns={"YEAR_NOTIF": "YEAR"})
full_pop_manaus_df = full_pop_manaus_df.rename(columns={"MUNIC_RES": "MUN_RESI"})

# %% [markdown]
# #### Gets number of cases and population per municipality per year

# %%
cases_per_year_df = pd.merge(tot_cases_manaus_by_year, full_pop_manaus_df, on=['MUN_RESI', 'YEAR'], how='inner')
cases_per_year_df = cases_per_year_df[['MUN_RESI', 'YEAR', 'TOTAL_CASES', 'POPULATION']]
cases_per_year_df
# Out:
#   MUN_RESI  YEAR  TOTAL_CASES  POPULATION
# 0   130260  2017        16042     2130264
# 1   130260  2018        12618     2145444
# 2   130260  2019         9720     2182763
# 3   130260  2020         7501     2219580
# 4   130260  2021         6198     2255903

# %% [markdown]
# #### Gets annual incidence per municipality per year

# %%
annual_incidence_df = cases_per_year_df

annual_incidence_df['CASES_PER_100K'] = (annual_incidence_df['TOTAL_CASES'].astype(int) / annual_incidence_df['POPULATION'].astype(int)) * 100000
annual_incidence_df = annual_incidence_df.sort_values(by='CASES_PER_100K', ascending=False)
annual_incidence_df
# Out:
#   MUN_RESI  YEAR  TOTAL_CASES  POPULATION  CASES_PER_100K
# 0   130260  2017        16042     2130264      753.052204
# 1   130260  2018        12618     2145444      588.130009
# 2   130260  2019         9720     2182763      445.307163
# 3   130260  2020         7501     2219580      337.946819
# 4   130260  2021         6198     2255903      274.745856

# %% [markdown]
# #### Gets total number of cases in each municipality from 2003 to 2023

# %%
tot_cases_manaus = tot_cases_brazil[tot_cases_brazil.get('MUN_RESI') == '130260']
tot_cases_manaus
# Out:
#     MUN_RESI  TOTAL_CASES
# 111   130260        52079

# %%
full_cases_df = pd.merge(tot_cases_manaus, full_pop_manaus_df, on=['MUN_RESI'], how='inner')
full_cases_df
# Out:
#   MUN_RESI  TOTAL_CASES  YEAR  POPULATION
# 0   130260        52079  2017     2130264
# 1   130260        52079  2018     2145444
# 2   130260        52079  2019     2182763
# 3   130260        52079  2020     2219580
# 4   130260        52079  2021     2255903

# %% [markdown]
# #### Mean population of Manaus from 2017 to 2021

# %%
mean_population_df = full_cases_df.groupby('MUN_RESI').agg({
    'POPULATION': 'mean',
    'TOTAL_CASES': 'first'
}).reset_index()

mean_population_df = mean_population_df.rename(columns={"POPULATION": "MEAN_POPULATION"})
mean_population_df
# Out:
#   MUN_RESI  MEAN_POPULATION  TOTAL_CASES
# 0   130260        2186790.8        52079

# %% [markdown]
# #### Mean incidence of cases in Manaus from 2017 to 2021

# %%
mean_incidence_df = mean_population_df

mean_incidence_df['CASES_PER_100K'] = (mean_incidence_df['TOTAL_CASES'].astype(int) / mean_incidence_df['MEAN_POPULATION'].astype(int)) * 100000
mean_incidence_df = mean_incidence_df.sort_values(by='CASES_PER_100K', ascending=False)
mean_incidence_df
# Out:
#   MUN_RESI  MEAN_POPULATION  TOTAL_CASES  CASES_PER_100K
# 0   130260        2186790.8        52079     2381.527261

# %%
manaus_cases_per_year_df = cases_per_year_df
manaus_cases_per_year_df
# Out:
#   MUN_RESI  YEAR  TOTAL_CASES  POPULATION  CASES_PER_100K
# 0   130260  2017        16042     2130264      753.052204
# 1   130260  2018        12618     2145444      588.130009
# 2   130260  2019         9720     2182763      445.307163
# 3   130260  2020         7501     2219580      337.946819
# 4   130260  2021         6198     2255903      274.745856

# %%
manaus_rural_pop_df = manaus_cases_per_year_df.assign(RURAL_POP = manaus_cases_per_year_df.get('POPULATION')*0.45/100)
manaus_rural_pop_df['RURAL_POP'] = manaus_rural_pop_df['RURAL_POP'].round()
manaus_rural_pop_df = manaus_rural_pop_df.assign(RURAL_CASES = manaus_rural_pop_df.get('TOTAL_CASES')*35.75/100)

manaus_rural_pop_df
# Out:
#   MUN_RESI  YEAR  TOTAL_CASES  POPULATION  CASES_PER_100K  RURAL_POP  \
# 0   130260  2017        16042     2130264      753.052204     9586.0
# 1   130260  2018        12618     2145444      588.130009     9654.0
# 2   130260  2019         9720     2182763      445.307163     9822.0
# 3   130260  2020         7501     2219580      337.946819     9988.0
# 4   130260  2021         6198     2255903      274.745856    10152.0
#
#    RURAL_CASES
# 0    5735.0150
# 1    4510.9350
# 2    3474.9000
# 3    2681.6075
# 4    2215.7850

# %%
manaus_rural_pop_df['RURAL_INCIDENCE'] = (manaus_rural_pop_df['RURAL_CASES'].astype(int) / manaus_rural_pop_df['RURAL_POP'].astype(int)) * 100000
#manaus_rural_pop_df = manaus_rural_pop_df.sort_values(by='CASES_PER_100K', ascending=False)
manaus_rural_pop_df
# Out:
#   MUN_RESI  YEAR  TOTAL_CASES  POPULATION  CASES_PER_100K  RURAL_POP  \
# 0   130260  2017        16042     2130264      753.052204     9586.0
# 1   130260  2018        12618     2145444      588.130009     9654.0
# 2   130260  2019         9720     2182763      445.307163     9822.0
# 3   130260  2020         7501     2219580      337.946819     9988.0
# 4   130260  2021         6198     2255903      274.745856    10152.0
#
#    RURAL_CASES  RURAL_INCIDENCE
# 0    5735.0150     59826.830795
# 1    4510.9350     46716.386990
# 2    3474.9000     35369.578497
# 3    2681.6075     26842.210653
# 4    2215.7850     21818.360914

# %%
manaus_pop_difference_df = manaus_rural_pop_df

manaus_pop_difference_df['POPULATION_DIFF'] = manaus_pop_difference_df['POPULATION'] - manaus_pop_difference_df['POPULATION'].shift(1)
manaus_pop_difference_df['POPULATION_DIFF'].iloc[0] = 0

manaus_pop_difference_df['RURAL_POP_DIFF'] = manaus_pop_difference_df['RURAL_POP'] - manaus_pop_difference_df['RURAL_POP'].shift(1)
manaus_pop_difference_df['RURAL_POP_DIFF'].iloc[0] = 0

manaus_pop_difference_df
# Out:
# C:\Users\ilana\anaconda3\lib\site-packages\pandas\core\indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
#   MUN_RESI  YEAR  TOTAL_CASES  POPULATION  CASES_PER_100K  RURAL_POP  \
# 0   130260  2017        16042     2130264      753.052204     9586.0
# 1   130260  2018        12618     2145444      588.130009     9654.0
# 2   130260  2019         9720     2182763      445.307163     9822.0
# 3   130260  2020         7501     2219580      337.946819     9988.0
# 4   130260  2021         6198     2255903      274.745856    10152.0
#
#    RURAL_CASES  RURAL_INCIDENCE  POPULATION_DIFF  RURAL_POP_DIFF
# 0    5735.0150     59826.830795              0.0             0.0
# 1    4510.9350     46716.386990          15180.0            68.0
# ...

# %% [markdown]
# Total increase in population between 2017 and 2021:

# %%
manaus_pop_difference_df.get('RURAL_POP').iloc[-1]-manaus_pop_difference_df.get('RURAL_POP').iloc[0]
# Out:
# 566.0

# %% [markdown]
# Approximating a birth rate between first and last years:

# %%
(manaus_pop_difference_df.get('RURAL_POP').iloc[-1]-manaus_pop_difference_df.get('RURAL_POP').iloc[0])/(len(manaus_pop_difference_df)-1)
# Out:
# 141.5

# %% [markdown]
# About 142 births per year from 2017 to 2021

# %% [markdown]
# Getting a mean rural population

# %%
mean_rural_pop = manaus_pop_difference_df.loc[0:4, 'RURAL_POP'].mean()
mean_rural_pop
# Out:
# 9840.4

# %% [markdown]
# Around 9840 people living in the rural areas of Manaus

# %%
manaus_rural_births_per_day = (manaus_pop_difference_df.get('RURAL_POP').iloc[-1]-manaus_pop_difference_df.get('RURAL_POP').iloc[0])/(len(manaus_pop_difference_df)-1)/365
manaus_rural_births_per_day
# Out:
# 0.38767123287671235

# %% [markdown]
# Around 0.388 births per day

# %%
manaus_rural_births_per_person_day = manaus_rural_births_per_day/mean_rural_pop
manaus_rural_births_per_person_day
# Out:
# 3.939588155732616e-05

# %% [markdown]
# Around 0.0000394 births per person per year ($\mu_H$)

# %% [markdown]
# #### Searching for monthly cases of malaria in residents of Manaus

# %%
manaus_resid
# Out:
#          COD_NOTI  DT_NOTIF    DT_ENVLO  DT_DIGIT SEM_NOTI  TIPO_LAM UF_NOTIF  \
# 0            2990  10/09/17  13/09/2017  13/09/17  37/2017         1       AM
# 1             421  31/01/17  03/02/2017  03/02/17  05/2017         1       AM
# 2            2991  10/09/17  13/09/2017  13/09/17  37/2017         1       AM
# 3            5196  09/12/17  14/12/2017  14/12/17  49/2017         1       AM
# 4            7891  24/08/17  25/08/2017  25/08/17  34/2017         1       AM
# ...           ...       ...         ...       ...      ...       ...      ...
# 1005991      2653  25/09/21  29/09/2021  28/09/21  38/2021         1       AM
# 1006093       181  03/11/21  04/11/2021  04/11/21  44/2021         1       AM
# 1006111    187216  08/10/21  10/10/2021  08/10/21  40/2021         1       AM
# 1006159       148  19/10/21  21/10/2021  21/10/21  42/2021         1       AM
# 1006319        67  02/08/21  03/08/2021  03/08/21  31/2021         1       AM
#
# ...

# %%
manaus_resid.columns
# Out:
# Index(['COD_NOTI', 'DT_NOTIF', 'DT_ENVLO', 'DT_DIGIT', 'SEM_NOTI', 'TIPO_LAM',
#        'UF_NOTIF', 'MUN_NOTI', 'COD_UNIN', 'COD_AGEN', 'DT_NASCI', 'ID_PACIE',
#        'ID_DIMEA', 'SEXO', 'RACA', 'PESO', 'PAIS_RES', 'UF_RESID', 'MUN_RESI',
#        'LOC_RESI', 'SINTOMAS', 'DT_SINTO', 'COD_OCUP', 'UF_INFEC', 'PAIS_INF',
#        'MUN_INFE', 'LOC_INFE', 'DT_EXAME', 'RES_EXAM', 'QTD_PARA', 'QTD_CRUZ',
#        'DT_TRATA', 'ESQUEMA', 'CO_FORMA_SANGUINEA',
#        'CO_FORMA_TECIDUAL_GAMETOCITO', 'HEMOPARASI', 'EXAME ',
#        'NU_ATIVIDADE_G6PD', 'NU_HEMOGLOBINA_TOTAL', 'EXAMINADOR', 'ID_LVC ',
#        'GESTANTE ', 'AMAMENTANDO', 'TEMP_AMAMENT', 'DIMEA_AMAMENT', 'VIVAX',
#        'FALCIPARUM', 'NIV_ESCO', 'YEAR_NOTIF'],
#       dtype='object')

# %% [markdown]
# Removes unused columns

# %%
manaus_resid_dropped_columns = manaus_resid.drop(columns=['DT_TRATA', 'ESQUEMA', 'CO_FORMA_SANGUINEA', 
                                'CO_FORMA_TECIDUAL_GAMETOCITO', 'EXAME ', 'NU_ATIVIDADE_G6PD', 
                                'NU_HEMOGLOBINA_TOTAL', 'EXAMINADOR', 'ID_LVC ', 'GESTANTE ', 
                                'AMAMENTANDO', 'TEMP_AMAMENT', 'DIMEA_AMAMENT', 'NIV_ESCO', 'FALCIPARUM',
                                'QTD_PARA', 'QTD_CRUZ', 'SEXO', 'RACA', 'PESO', 'COD_AGEN', 'DT_NASCI', 'ID_PACIE',
                                'ID_DIMEA', 'COD_UNIN', 'COD_NOTI', 'TIPO_LAM', 'DT_ENVLO', 'HEMOPARASI', 
                                'PAIS_INF', 'PAIS_RES', 'DT_DIGIT'])
manaus_resid_dropped_columns
# Out:
#          DT_NOTIF SEM_NOTI UF_NOTIF  MUN_NOTI UF_RESID  MUN_RESI  LOC_RESI  \
# 0        10/09/17  37/2017       AM    130260       AM  130260.0     267.0
# 1        31/01/17  05/2017       AM    130260       AM  130260.0     564.0
# 2        10/09/17  37/2017       AM    130260       AM  130260.0     267.0
# 3        09/12/17  49/2017       AM    130260       AM  130260.0     564.0
# 4        24/08/17  34/2017       AM    130260       AM  130260.0     565.0
# ...           ...      ...      ...       ...      ...       ...       ...
# 1005991  25/09/21  38/2021       AM    130260       AM  130260.0     577.0
# 1006093  03/11/21  44/2021       AM    130260       AM  130260.0     483.0
# 1006111  08/10/21  40/2021       AM    130260       AM  130260.0     395.0
# 1006159  19/10/21  42/2021       AM    130260       AM  130260.0     218.0
# 1006319  02/08/21  31/2021       AM    130260       AM  130260.0     490.0
#
# ...

# %%
manaus_resid_dropped_columns.columns
# Out:
# Index(['DT_NOTIF', 'SEM_NOTI', 'UF_NOTIF', 'MUN_NOTI', 'UF_RESID', 'MUN_RESI',
#        'LOC_RESI', 'SINTOMAS', 'DT_SINTO', 'COD_OCUP', 'UF_INFEC', 'MUN_INFE',
#        'LOC_INFE', 'DT_EXAME', 'RES_EXAM', 'VIVAX', 'YEAR_NOTIF'],
#       dtype='object')

# %%
manaus_resid_dropped_columns['DT_NOTIF'] = pd.to_datetime(manaus_resid_dropped_columns['DT_NOTIF'], format='%d/%m/%y')
manaus_resid_dropped_columns['MONTH_NOTIF'] = manaus_resid_dropped_columns['DT_NOTIF'].dt.strftime('%m/%Y')
manaus_resid_dropped_columns
# Out:
#           DT_NOTIF SEM_NOTI UF_NOTIF  MUN_NOTI UF_RESID  MUN_RESI  LOC_RESI  \
# 0       2017-09-10  37/2017       AM    130260       AM  130260.0     267.0
# 1       2017-01-31  05/2017       AM    130260       AM  130260.0     564.0
# 2       2017-09-10  37/2017       AM    130260       AM  130260.0     267.0
# 3       2017-12-09  49/2017       AM    130260       AM  130260.0     564.0
# 4       2017-08-24  34/2017       AM    130260       AM  130260.0     565.0
# ...            ...      ...      ...       ...      ...       ...       ...
# 1005991 2021-09-25  38/2021       AM    130260       AM  130260.0     577.0
# 1006093 2021-11-03  44/2021       AM    130260       AM  130260.0     483.0
# 1006111 2021-10-08  40/2021       AM    130260       AM  130260.0     395.0
# 1006159 2021-10-19  42/2021       AM    130260       AM  130260.0     218.0
# 1006319 2021-08-02  31/2021       AM    130260       AM  130260.0     490.0
#
# ...

# %%
manaus_resid_dropped_columns = manaus_resid_dropped_columns.drop(columns=['UF_INFEC', 'MUN_INFE', 'DT_EXAME'])
manaus_resid_dropped_columns
# Out:
#           DT_NOTIF SEM_NOTI UF_NOTIF  MUN_NOTI UF_RESID  MUN_RESI  LOC_RESI  \
# 0       2017-09-10  37/2017       AM    130260       AM  130260.0     267.0
# 1       2017-01-31  05/2017       AM    130260       AM  130260.0     564.0
# 2       2017-09-10  37/2017       AM    130260       AM  130260.0     267.0
# 3       2017-12-09  49/2017       AM    130260       AM  130260.0     564.0
# 4       2017-08-24  34/2017       AM    130260       AM  130260.0     565.0
# ...            ...      ...      ...       ...      ...       ...       ...
# 1005991 2021-09-25  38/2021       AM    130260       AM  130260.0     577.0
# 1006093 2021-11-03  44/2021       AM    130260       AM  130260.0     483.0
# 1006111 2021-10-08  40/2021       AM    130260       AM  130260.0     395.0
# 1006159 2021-10-19  42/2021       AM    130260       AM  130260.0     218.0
# 1006319 2021-08-02  31/2021       AM    130260       AM  130260.0     490.0
#
# ...

# %% [markdown]
# Gets total cases per month

# %%
cases_manaus_by_month = manaus_resid_dropped_columns[['MONTH_NOTIF']].groupby(['MONTH_NOTIF']).size().reset_index(name='TOTAL_CASES')#.sort_values(by='TOTAL_CASES', ascending=False)
cases_manaus_by_month['MONTH_NOTIF'] = cases_manaus_by_month['MONTH_NOTIF']#.astype(int)
cases_manaus_by_month
# Out:
#    MONTH_NOTIF  TOTAL_CASES
# 0      01/2017          983
# 1      01/2018         1618
# 2      01/2019          962
# 3      01/2020          850
# 4      01/2021          408
# 5      02/2017          616
# 6      02/2018         1259
# 7      02/2019          604
# 8      02/2020          617
# 9      02/2021          309
# 10     03/2017          663
# 11     03/2018         1069
# 12     03/2019          501
# 13     03/2020          592
# 14     03/2021          304
# 15     04/2017          537
# 16     04/2018          880
# 17     04/2019          593
# 18     04/2020          329
# 19     04/2021          289
# 20     05/2017          944
# 21     05/2018          847
# 22     05/2019          537
# 23     05/2020          394
# 24     05/2021          284
# 25     06/2017         1166
# 26     06/2018          727
# 27     06/2019          568
# 28     06/2020          519
# 29     06/2021          420
# 30     07/2017         1701
# 31     07/2018          964
# ...

# %%
cases_manaus_by_month['MONTH_NOTIF'] = pd.to_datetime(cases_manaus_by_month['MONTH_NOTIF'], format='%m/%Y')
cases_manaus_by_month = cases_manaus_by_month.sort_values(by='MONTH_NOTIF')
cases_manaus_by_month = cases_manaus_by_month.reset_index(drop=True)
cases_manaus_by_month
# Out:
#    MONTH_NOTIF  TOTAL_CASES
# 0   2017-01-01          983
# 1   2017-02-01          616
# 2   2017-03-01          663
# 3   2017-04-01          537
# 4   2017-05-01          944
# 5   2017-06-01         1166
# 6   2017-07-01         1701
# 7   2017-08-01         2162
# 8   2017-09-01         2291
# 9   2017-10-01         1864
# 10  2017-11-01         1534
# 11  2017-12-01         1581
# 12  2018-01-01         1618
# 13  2018-02-01         1259
# 14  2018-03-01         1069
# 15  2018-04-01          880
# 16  2018-05-01          847
# 17  2018-06-01          727
# 18  2018-07-01          964
# 19  2018-08-01         1626
# 20  2018-09-01         1235
# 21  2018-10-01         1013
# 22  2018-11-01          704
# 23  2018-12-01          676
# 24  2019-01-01          962
# 25  2019-02-01          604
# 26  2019-03-01          501
# 27  2019-04-01          593
# 28  2019-05-01          537
# 29  2019-06-01          568
# 30  2019-07-01          912
# 31  2019-08-01         1099
# ...

# %%
cases_manaus_by_month['TOTAL_CASES'].sum()
# Out:
# 52079

# %% [markdown]
# Gets approximate number of rural cases per month

# %%
cases_manaus_by_month = cases_manaus_by_month.assign(RURAL_CASES = cases_manaus_by_month.get('TOTAL_CASES')*35.75/100)
cases_manaus_by_month
# Out:
#    MONTH_NOTIF  TOTAL_CASES  RURAL_CASES
# 0   2017-01-01          983     351.4225
# 1   2017-02-01          616     220.2200
# 2   2017-03-01          663     237.0225
# 3   2017-04-01          537     191.9775
# 4   2017-05-01          944     337.4800
# 5   2017-06-01         1166     416.8450
# 6   2017-07-01         1701     608.1075
# 7   2017-08-01         2162     772.9150
# 8   2017-09-01         2291     819.0325
# 9   2017-10-01         1864     666.3800
# 10  2017-11-01         1534     548.4050
# 11  2017-12-01         1581     565.2075
# 12  2018-01-01         1618     578.4350
# 13  2018-02-01         1259     450.0925
# 14  2018-03-01         1069     382.1675
# 15  2018-04-01          880     314.6000
# 16  2018-05-01          847     302.8025
# 17  2018-06-01          727     259.9025
# 18  2018-07-01          964     344.6300
# 19  2018-08-01         1626     581.2950
# 20  2018-09-01         1235     441.5125
# 21  2018-10-01         1013     362.1475
# ...

# %%
cases_2017 = cases_manaus_by_month[cases_manaus_by_month['MONTH_NOTIF'].dt.year == 2017]
cases_2017.get('TOTAL_CASES').sum()
# Out:
# 16042

# %%
cases_2018 = cases_manaus_by_month[cases_manaus_by_month['MONTH_NOTIF'].dt.year == 2018]
cases_2018.get('TOTAL_CASES').sum()
# Out:
# 12618

# %%
cases_2019 = cases_manaus_by_month[cases_manaus_by_month['MONTH_NOTIF'].dt.year == 2019]
cases_2019.get('TOTAL_CASES').sum()
# Out:
# 9720

# %%
cases_2020 = cases_manaus_by_month[cases_manaus_by_month['MONTH_NOTIF'].dt.year == 2020]
cases_2020.get('TOTAL_CASES').sum()
# Out:
# 7501

# %%
cases_2021 = cases_manaus_by_month[cases_manaus_by_month['MONTH_NOTIF'].dt.year == 2021]
cases_2021.get('TOTAL_CASES').sum()
# Out:
# 6198

# %% [markdown]
# Total cases per month

# %%
cases_manaus_by_month['MONTH_NOTIF'] = pd.to_datetime(cases_manaus_by_month['MONTH_NOTIF'])

plt.figure(figsize=(12, 6))
plt.plot(cases_manaus_by_month['MONTH_NOTIF'], cases_manaus_by_month['TOTAL_CASES'], marker='o')

plt.title('Total Cases per Month')
plt.xlabel('Month')
plt.ylabel('Total Cases')
plt.xticks(rotation=45)  
plt.grid(True)  

plt.tight_layout()
plt.show()

# %% [markdown]
# Rural cases per month

# %%
cases_manaus_by_month['MONTH_NOTIF'] = pd.to_datetime(cases_manaus_by_month['MONTH_NOTIF'])

plt.figure(figsize=(12, 6))
plt.plot(cases_manaus_by_month['MONTH_NOTIF'], cases_manaus_by_month['RURAL_CASES'], marker='o')

plt.title('Rural Cases per Month')
plt.xlabel('Month')
plt.ylabel('Rural Cases')
plt.xticks(rotation=45)  
plt.grid(True)  

plt.tight_layout()
plt.show()

# %%
cases_manaus_by_month['MONTH_NOTIF'] = pd.to_datetime(cases_manaus_by_month['MONTH_NOTIF'])
cases_manaus_by_year = cases_manaus_by_month.groupby(cases_manaus_by_month['MONTH_NOTIF'].dt.year)['TOTAL_CASES', 'RURAL_CASES'].sum().reset_index()
cases_manaus_by_year.columns = ['YEAR', 'TOTAL_CASES', 'RURAL_CASES']
cases_manaus_by_year
# Out:
# <ipython-input-60-36382bd6011d>:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   cases_manaus_by_year = cases_manaus_by_month.groupby(cases_manaus_by_month['MONTH_NOTIF'].dt.year)['TOTAL_CASES', 'RURAL_CASES'].sum().reset_index()
#    YEAR  TOTAL_CASES  RURAL_CASES
# 0  2017        16042    5735.0150
# 1  2018        12618    4510.9350
# 2  2019         9720    3474.9000
# 3  2020         7501    2681.6075
# 4  2021         6198    2215.7850

# %% [markdown]
# Rural cases per year

# %%
plt.figure(figsize=(12, 6))
plt.plot(cases_manaus_by_year['YEAR'], cases_manaus_by_year['RURAL_CASES'], marker='o')

plt.title('Rural Cases per Year')
plt.xlabel('Year')
plt.ylabel('Rural Cases')
plt.xticks(rotation=45)  
plt.grid(True)  

plt.tight_layout()
plt.show()

# %%
cases_manaus_by_year.plot(kind='line', y='RURAL_CASES');
plt.show()
