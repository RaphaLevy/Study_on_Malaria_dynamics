# %%
import pandas as pd

# %%
parquet_2004 = pd.read_parquet('MALA_2004.parquet')
parquet_2004.to_csv('MALA_2004.csv')

malaria_2004_df = pd.read_csv('MALA_2004.csv')
malaria_2004_df
# Out:
#       Unnamed: 0  ID_MUNICIP  ID_UNIDADE  DT_NOTIFIC CS_RACA CS_ESCOLAR  \
# 0              0     2708006     2004054    20040126       4        3
# 1              1     2704302        8133    20040204
# 2              2     2704302     2720035    20040106       4        9
# 3              3     2704302     2720035    20040107       1        9
# 4              4     2704302     2720035    20040102       4        9
# ...          ...         ...         ...         ...     ...        ...
# 3727        3727     1705508     2764931    20040213       4        3
# 3728        3728     1705508     2764931    20040107       1        4
# 3729        3729     1712009     2467593    20040301       2        3
# 3730        3730     1713809     2680270    20040218       1        2
# 3731        3731     1712009     2467593    20040301       3        3
#
#       NU_ANO  SEM_NOT SG_UF_NOT ID_REGIONA  ...  CON_CONFIR  CON_INF_MU  \
# ...

# %%
parquet_2005 = pd.read_parquet('MALA_2005.parquet')
parquet_2005.to_csv('MALA_2005.csv')

malaria_2005_df = pd.read_csv('MALA_2005.csv')
malaria_2005_df
# Out:
#       Unnamed: 0  ID_MUNICIP  ID_UNIDADE  DT_NOTIFIC CS_RACA CS_ESCOLAR  \
# 0              0     2704302     2720035    20050124       4        4
# 1              1     2704302     2720035    20050127       1        3
# 2              2     2704302     2720035    20050105       1        3
# 3              3     2704302        8133    20050706
# 4              4     2704302     2720035    20050815       4        3
# ...          ...         ...         ...         ...     ...        ...
# 4593        4593     3547304     2746964    20051104                2
# 4594        4594     3524402     2085038    20050530       1        4
# 4595        4595     3524402     2096412    20050808       4        3
# 4596        4596     3515350     2751208    20051220       2        3
# 4597        4597     3547809     2084090    20051011
#
#       NU_ANO  SEM_NOT SG_UF_NOT ID_REGIONA  ...  CON_CONFIR  CON_INF_MU  \
# 0       2005    42005        AL        001  ...           2     1301852
# ...

# %%
parquet_2006 = pd.read_parquet('MALA_2006.parquet')
parquet_2006.to_csv('MALA_2006.csv')

malaria_2006_df = pd.read_csv('MALA_2006.csv')
malaria_2006_df
# Out:
#       Unnamed: 0  ID_MUNICIP  ID_UNIDADE  DT_NOTIFIC CS_RACA CS_ESCOLAR  \
# 0              0     2704302     2720035    20060117       1        5
# 1              1     2704302     2720035    20060414       1        4
# 2              2     2704302     2720035    20060807       4        3
# 3              3     2704302     2009129    20060621                3
# 4              4     2927408        5428    20060627       9        9
# ...          ...         ...         ...         ...     ...        ...
# 3691        3691     3509502     2079798    20061202       1        9
# 3692        3692     3509502     2079798    20061130       1        9
# 3693        3693     3509502     2079798    20061206       2        9
# 3694        3694     3509502     2079798    20061214       1        4
# 3695        3695     1720002     2469529    20060607       1        3
#
#       NU_ANO   SEM_NOT SG_UF_NOT ID_REGIONA  ...  CON_CONFIR  CON_INF_MU  \
# ...

# %%
parquet_2007 = pd.read_parquet('MALA_2007.parquet')
parquet_2007.to_csv('MALA_2007.csv')

malaria_2007_df = pd.read_csv('MALA_2007.csv')
malaria_2007_df
# Out:
#       Unnamed: 0  TP_NOT ID_AGRAVO  DT_NOTIFIC  SEM_NOT  NU_ANO  SG_UF_NOT  \
# 0              0       2      B54     20070116   200703    2007         31
# 1              1       2      B54     20070119   200703    2007         31
# 2              2       2      B54     20070112   200702    2007         22
# 3              3       2      B54     20070108   200702    2007         22
# 4              4       2      B54     20070123   200704    2007         32
# ...          ...     ...       ...         ...      ...     ...        ...
# 3516        3516       2      B54     20071218   200751    2007         41
# 3517        3517       2      B54     20071218   200751    2007         41
# 3518        3518       2      B54     20071226   200752    2007         41
# 3519        3519       2      B54     20071207   200749    2007         42
# 3520        3520       2      B54     20071226   200752    2007         29
#
# ...

# %%
parquet_2008 = pd.read_parquet('MALA_2008.parquet')
parquet_2008.to_csv('MALA_2008.csv')

malaria_2008_df = pd.read_csv('MALA_2008.csv')
malaria_2008_df
# Out:
#       Unnamed: 0  TP_NOT ID_AGRAVO  DT_NOTIFIC  SEM_NOT  NU_ANO  SG_UF_NOT  \
# 0              0       2      B54     20080102   200801    2008         43
# 1              1       2      B54     20080111   200802    2008         35
# 2              2       2      B54     20080102   200801    2008         32
# 3              3       2      B54     20080128   200805    2008         35
# 4              4       2      B54     20080105   200801    2008         35
# ...          ...     ...       ...         ...      ...     ...        ...
# 2534        2534       2      B54     20081216   200851    2008         29
# 2535        2535       2      B54     20081226   200852    2008         29
# 2536        2536       2      B54     20081208   200850    2008         35
# 2537        2537       2      B54     20081229   200853    2008         43
# 2538        2538       2      B54     20081216   200851    2008         31
#
# ...

# %%
parquet_2009 = pd.read_parquet('MALA_2009.parquet')
parquet_2009.to_csv('MALA_2009.csv')

malaria_2009_df = pd.read_csv('MALA_2009.csv')
malaria_2009_df
# Out:
#       Unnamed: 0  TP_NOT ID_AGRAVO  DT_NOTIFIC  SEM_NOT  NU_ANO  SG_UF_NOT  \
# 0              0       2      B54     20090101   200853    2009         42
# 1              1       2      B54     20090101   200853    2009         31
# 2              2       2      B54     20090102   200853    2009         27
# 3              3       2      B54     20090102   200853    2009         35
# 4              4       2      B54     20090102   200853    2009         50
# ...          ...     ...       ...         ...      ...     ...        ...
# 2549        2549       2      B54     20091231   200952    2009         26
# 2550        2550       2      B54     20091231   200952    2009         41
# 2551        2551       2      B54     20091231   200952    2009         41
# 2552        2552       2      B54     20091231   200952    2009         41
# 2553        2553       2      B54     20091231   200952    2009         26
#
# ...

# %%
parquet_2010 = pd.read_parquet('MALA_2010.parquet')
parquet_2010.to_csv('MALA_2010.csv')

malaria_2010_df = pd.read_csv('MALA_2010.csv')
malaria_2010_df
# Out:
#       Unnamed: 0  TP_NOT ID_AGRAVO  DT_NOTIFIC  SEM_NOT  NU_ANO  SG_UF_NOT  \
# 0              0       2      B54     20100112   201002    2010         42
# 1              1       2      B54     20100125   201004    2010         35
# 2              2       2      B54     20100121   201003    2010         32
# 3              3       2      B54     20100104   201001    2010         41
# 4              4       2      B54     20100106   201001    2010         41
# ...          ...     ...       ...         ...      ...     ...        ...
# 3036        3036       2      B54     20101224   201051    2010         26
# 3037        3037       2      B54     20101229   201052    2010         26
# 3038        3038       2      B54     20101221   201051    2010         31
# 3039        3039       2      B54     20101228   201052    2010         31
# 3040        3040       2      B54     20101209   201049    2010         32
#
# ...

# %%
parquet_2011 = pd.read_parquet('MALA_2011.parquet')
parquet_2011.to_csv('MALA_2011.csv')

malaria_2011_df = pd.read_csv('MALA_2011.csv')
malaria_2011_df
# Out:
#       Unnamed: 0  TP_NOT ID_AGRAVO  DT_NOTIFIC  SEM_NOT  NU_ANO  SG_UF_NOT  \
# 0              0       2      B54     20110101   201052    2011         35
# 1              1       2      B54     20110101   201052    2011         35
# 2              2       2      B54     20110101   201052    2011         52
# 3              3       2      B54     20110101   201052    2011         35
# 4              4       2      B54     20110101   201052    2011         32
# ...          ...     ...       ...         ...      ...     ...        ...
# 2666        2666       2      B54     20111229   201152    2011         32
# 2667        2667       2      B54     20111229   201152    2011         32
# 2668        2668       2      B54     20111229   201152    2011         32
# 2669        2669       2      B54     20111229   201152    2011         41
# 2670        2670       2      B54     20111231   201152    2011         35
#
# ...

# %%
parquet_2012 = pd.read_parquet('MALA_2012.parquet')
parquet_2012.to_csv('MALA_2012.csv')

malaria_2012_df = pd.read_csv('MALA_2012.csv')
malaria_2012_df
# Out:
#       Unnamed: 0  TP_NOT ID_AGRAVO  DT_NOTIFIC  SEM_NOT  NU_ANO  SG_UF_NOT  \
# 0              0       2      B54     20120101   201201    2012         52
# 1              1       2      B54     20120101   201201    2012         22
# 2              2       2      B54     20120101   201201    2012         50
# 3              3       2      B54     20120102   201201    2012         35
# 4              4       2      B54     20120102   201201    2012         52
# ...          ...     ...       ...         ...      ...     ...        ...
# 3217        3217       2      B54     20121231   201301    2012         32
# 3218        3218       2      B54     20121231   201301    2012         29
# 3219        3219       2      B54     20121231   201301    2012         52
# 3220        3220       2      B54     20121231   201301    2012         52
# 3221        3221       2      B54     20121231   201301    2012         52
#
# ...

# %%
parquet_2013 = pd.read_parquet('MALA_2013.parquet')
parquet_2013.to_csv('MALA_2013.csv')

malaria_2013_df = pd.read_csv('MALA_2013.csv')
malaria_2013_df
# Out:
#       Unnamed: 0  TP_NOT ID_AGRAVO  DT_NOTIFIC  SEM_NOT  NU_ANO  SG_UF_NOT  \
# 0              0       2      B54     20130101   201301    2013         33
# 1              1       2      B54     20130101   201301    2013         29
# 2              2       2      B54     20130101   201301    2013         31
# 3              3       2      B54     20130101   201301    2013         35
# 4              4       2      B54     20130102   201301    2013         43
# ...          ...     ...       ...         ...      ...     ...        ...
# 3339        3339       2      B54     20131231   201401    2013         42
# 3340        3340       2      B54     20131231   201401    2013         42
# 3341        3341       2      B54     20131231   201401    2013         35
# 3342        3342       2      B54     20131231   201401    2013         31
# 3343        3343       2      B54     20131231   201401    2013         33
#
# ...

# %%
malaria_2013_df.columns
# Out:
# Index(['Unnamed: 0', 'TP_NOT', 'ID_AGRAVO', 'DT_NOTIFIC', 'SEM_NOT', 'NU_ANO',
#        'SG_UF_NOT', 'ID_MUNICIP', 'ID_REGIONA', 'ID_UNIDADE', 'DT_SIN_PRI',
#        'SEM_PRI', 'ANO_NASC', 'NU_IDADE_N', 'CS_SEXO', 'CS_GESTANT', 'CS_RACA',
#        'CS_ESCOL_N', 'SG_UF', 'ID_MN_RESI', 'ID_RG_RESI', 'ID_PAIS',
#        'DT_INVEST', 'ID_OCUPA_N', 'CLASSI_FIN', 'AT_ATIVIDA', 'AT_LAMINA',
#        'AT_SINTOMA', 'TPAUTOCTO', 'COUFINF', 'COPAISINF', 'COMUNINF',
#        'LOC_INF', 'DEXAME', 'RESULT', 'PMM', 'PCRUZ', 'TRA_ESQUEM',
#        'DSTRAESQUE', 'DTRATA', 'NU_LOTE_I', 'DT_ENCERRA', 'DT_DIGITA',
#        'DT_TRANSUS', 'DT_TRANSDM', 'DT_TRANSSM', 'DT_TRANSRM', 'DT_TRANSRS',
#        'DT_TRANSSE', 'NU_LOTE_V', 'NU_LOTE_H'],
#       dtype='object')

# %%
malaria_2004_df.columns
# Out:
# Index(['Unnamed: 0', 'ID_MUNICIP', 'ID_UNIDADE', 'DT_NOTIFIC', 'CS_RACA',
#        'CS_ESCOLAR', 'NU_ANO', 'SEM_NOT', 'SG_UF_NOT', 'ID_REGIONA',
#        'DT_SIN_PRI', 'SEM_PRI', 'NU_IDADE', 'CS_SEXO', 'ID_MN_RESI', 'SG_UF',
#        'ID_PAIS', 'ID_DG_NOT', 'ID_EV_NOT', 'ANT_DT_INV', 'OCUPACAO',
#        'TRANSFU', 'DTTRANSFU', 'UTRANSFU', 'UFTRANSFU', 'PTRANSFU', 'MTRANSFU',
#        'PUSUARIO', 'PMALARIA', 'AMALARIA', 'ASSINTOM', 'FEBRE', 'CALAFRIO',
#        'SUDORESE', 'CLI_OUTRO', 'CD_OUTRO', 'GESTANTE', 'HOSPITAL', 'DINTERNA',
#        'UFINTERNA', 'MINTERNA', 'DEXAME', 'PMM', 'PCRUZ', 'RESULT', 'CLOROQ',
#        'PRIMAQ', 'TETRAC', 'MEFLOQ', 'ARTESU', 'QUININO', 'ARTEM', 'CLIND',
#        'CLOROQI', 'QUININOI', 'ARTEI', 'ARTEMI', 'CLINDI', 'DOXOCI', 'SOUTROS',
#        'DTRATA', 'CON_CLASSI', 'CON_CONFIR', 'CON_INF_MU', 'CON_INF_UF',
#        'CON_INF_PA', 'CON_DOENCA', 'CON_EVOLUC', 'CON_DT_OBI', 'CON_DT_ENC',
#        'IN_VINCULA', 'NDUPLIC'],
#       dtype='object')

# %%
malaria_2004_df.columns.difference(malaria_2013_df.columns)
# Out:
# Index(['AMALARIA', 'ANT_DT_INV', 'ARTEI', 'ARTEM', 'ARTEMI', 'ARTESU',
#        'ASSINTOM', 'CALAFRIO', 'CD_OUTRO', 'CLIND', 'CLINDI', 'CLI_OUTRO',
#        'CLOROQ', 'CLOROQI', 'CON_CLASSI', 'CON_CONFIR', 'CON_DOENCA',
#        'CON_DT_ENC', 'CON_DT_OBI', 'CON_EVOLUC', 'CON_INF_MU', 'CON_INF_PA',
#        'CON_INF_UF', 'CS_ESCOLAR', 'DINTERNA', 'DOXOCI', 'DTTRANSFU', 'FEBRE',
#        'GESTANTE', 'HOSPITAL', 'ID_DG_NOT', 'ID_EV_NOT', 'IN_VINCULA',
#        'MEFLOQ', 'MINTERNA', 'MTRANSFU', 'NDUPLIC', 'NU_IDADE', 'OCUPACAO',
#        'PMALARIA', 'PRIMAQ', 'PTRANSFU', 'PUSUARIO', 'QUININO', 'QUININOI',
#        'SOUTROS', 'SUDORESE', 'TETRAC', 'TRANSFU', 'UFINTERNA', 'UFTRANSFU',
#        'UTRANSFU'],
#       dtype='object')

# %%
malaria_2013_df.columns.difference(malaria_2004_df.columns)
# Out:
# Index(['ANO_NASC', 'AT_ATIVIDA', 'AT_LAMINA', 'AT_SINTOMA', 'CLASSI_FIN',
#        'COMUNINF', 'COPAISINF', 'COUFINF', 'CS_ESCOL_N', 'CS_GESTANT',
#        'DSTRAESQUE', 'DT_DIGITA', 'DT_ENCERRA', 'DT_INVEST', 'DT_TRANSDM',
#        'DT_TRANSRM', 'DT_TRANSRS', 'DT_TRANSSE', 'DT_TRANSSM', 'DT_TRANSUS',
#        'ID_AGRAVO', 'ID_OCUPA_N', 'ID_RG_RESI', 'LOC_INF', 'NU_IDADE_N',
#        'NU_LOTE_H', 'NU_LOTE_I', 'NU_LOTE_V', 'TPAUTOCTO', 'TP_NOT',
#        'TRA_ESQUEM'],
#       dtype='object')

# %%
common_columns = malaria_2013_df.columns.intersection(malaria_2004_df.columns)
common_columns
# Out:
# Index(['Unnamed: 0', 'DT_NOTIFIC', 'SEM_NOT', 'NU_ANO', 'SG_UF_NOT',
#        'ID_MUNICIP', 'ID_REGIONA', 'ID_UNIDADE', 'DT_SIN_PRI', 'SEM_PRI',
#        'CS_SEXO', 'CS_RACA', 'SG_UF', 'ID_MN_RESI', 'ID_PAIS', 'DEXAME',
#        'RESULT', 'PMM', 'PCRUZ', 'DTRATA'],
#       dtype='object')

# %%
filter_2004 = malaria_2004_df.get(common_columns)
filter_2005 = malaria_2005_df.get(common_columns)
filter_2006 = malaria_2006_df.get(common_columns)
filter_2007 = malaria_2007_df.get(common_columns)
filter_2008 = malaria_2008_df.get(common_columns)
filter_2009 = malaria_2009_df.get(common_columns)
filter_2010 = malaria_2010_df.get(common_columns)
filter_2011 = malaria_2011_df.get(common_columns)
filter_2012 = malaria_2012_df.get(common_columns)
filter_2013 = malaria_2013_df.get(common_columns)

# %%
filter_2004
# Out:
#       Unnamed: 0  DT_NOTIFIC  SEM_NOT  NU_ANO SG_UF_NOT  ID_MUNICIP  \
# 0              0    20040126    42004    2004        AL     2708006
# 1              1    20040204    52004    2004        AL     2704302
# 2              2    20040106    12004    2004        AL     2704302
# 3              3    20040107    12004    2004        AL     2704302
# 4              4    20040102   532003    2004        AL     2704302
# ...          ...         ...      ...     ...       ...         ...
# 3727        3727    20040213    62004    2004        TO     1705508
# 3728        3728    20040107    12004    2004        TO     1705508
# 3729        3729    20040301    92004    2004        TO     1712009
# 3730        3730    20040218    72004    2004        TO     1713809
# 3731        3731    20040301    92004    2004        TO     1712009
#
#      ID_REGIONA  ID_UNIDADE  DT_SIN_PRI  SEM_PRI CS_SEXO CS_RACA SG_UF  \
# 0           008     2004054    20040120    32004       M       4    AL
# ...

# %%
full_df = pd.concat([filter_2004, filter_2005, filter_2006,
                     filter_2007, filter_2008, filter_2009,
                     filter_2010, filter_2011, filter_2012, filter_2013])
full_df
# Out:
#       Unnamed: 0  DT_NOTIFIC   SEM_NOT  NU_ANO SG_UF_NOT  ID_MUNICIP  \
# 0              0    20040126   42004.0    2004        AL     2708006
# 1              1    20040204   52004.0    2004        AL     2704302
# 2              2    20040106   12004.0    2004        AL     2704302
# 3              3    20040107   12004.0    2004        AL     2704302
# 4              4    20040102  532003.0    2004        AL     2704302
# ...          ...         ...       ...     ...       ...         ...
# 3339        3339    20131231  201401.0    2013        42      420820
# 3340        3340    20131231  201401.0    2013        42      420910
# 3341        3341    20131231  201401.0    2013        35      354340
# 3342        3342    20131231  201401.0    2013        31      310710
# 3343        3343    20131231  201401.0    2013        33      330455
#
#      ID_REGIONA ID_UNIDADE  DT_SIN_PRI   SEM_PRI CS_SEXO CS_RACA SG_UF  \
# ...
