# %%
import pandas as pd
import numpy as np

# %%
import requests

climate_api = "https://api.mosqlimate.org/api/datastore/climate/"

page = 1 # total amount of pages is returned in the request
per_page = 100
pagination = f"?page={page}&per_page={per_page}&"
filters = "start=%s&end=%s" % ("2024-06-01", "2024-08-12")

resp = requests.get(climate_api + pagination + filters)

# Or you can add a geocode to the filters
geocode = 1302603
resp = requests.get(
    climate_api + 
    pagination + 
    filters +
    f"&geocode={geocode}"
)

items = resp.json()["items"] # JSON data in dict format
resp.json()["pagination"] # Pagination*
# Out:
# {'items': 66, 'total_items': 66, 'page': 1, 'total_pages': 1, 'per_page': 100}

# %%
items
# Out:
# [{'date': '2024-06-01',
#   'geocodigo': 1302603,
#   'temp_min': 24.2908,
#   'temp_med': 25.6076,
#   'temp_max': 26.6718,
#   'precip_min': 0.0044,
#   'precip_med': 0.3055,
#   'precip_max': 1.0001,
#   'precip_tot': 2.4442,
#   'pressao_min': 0.9985,
#   'pressao_med': 1.0001,
#   'pressao_max': 1.0018,
#   'umid_min': 86.1346,
#   'umid_med': 91.5237,
#   'umid_max': 95.9031},
#  {'date': '2024-06-02',
#   'geocodigo': 1302603,
#   'temp_min': 24.3025,
#   'temp_med': 26.9596,
#   'temp_max': 31.0277,
#   'precip_min': 0.0,
#   'precip_med': 0.0925,
#   'precip_max': 0.3632,
#   'precip_tot': 0.74,
#   'pressao_min': 0.9969,
#   'pressao_med': 0.9995,
#   'pressao_max': 1.0009,
#   'umid_min': 67.6306,
#   'umid_med': 85.9284,
#   'umid_max': 97.0995},
#  {'date': '2024-06-03',
#   'geocodigo': 1302603,
#   'temp_min': 25.1499,
#   'temp_med': 26.5381,
#   'temp_max': 28.5926,
#   'precip_min': 0.0,
#   'precip_med': 0.0789,
#   'precip_max': 0.3546,
#   'precip_tot': 0.6315,
#   'pressao_min': 0.9987,
#   'pressao_med': 1.0003,
#   'pressao_max': 1.0021,
#   'umid_min': 79.661,
#   'umid_med': 88.6693,
#   'umid_max': 95.0063},
#  {'date': '2024-06-04',
#   'geocodigo': 1302603,
#   'temp_min': 24.0487,
#   'temp_med': 27.2753,
#   'temp_max': 31.6334,
#   'precip_min': 0.0,
#   'precip_med': 0.0118,
#   'precip_max': 0.0384,
#   'precip_tot': 0.0943,
#   'pressao_min': 0.997,
#   'pressao_med': 0.9993,
#   'pressao_max': 1.0008,
#   'umid_min': 65.4224,
#   'umid_med': 85.5136,
#   'umid_max': 97.142},
#  {'date': '2024-06-05',
#   'geocodigo': 1302603,
#   'temp_min': 25.5905,
#   'temp_med': 27.9201,
#   'temp_max': 31.335,
#   'precip_min': 0.0,
#   'precip_med': 0.0631,
#   'precip_max': 0.3092,
#   'precip_tot': 0.5049,
#   'pressao_min': 0.9967,
#   'pressao_med': 0.9988,
#   'pressao_max': 1.0002,
#   'umid_min': 66.8854,
#   'umid_med': 82.6499,
#   'umid_max': 92.8523},
#  {'date': '2024-06-06',
#   'geocodigo': 1302603,
#   'temp_min': 25.1412,
#   'temp_med': 27.1886,
#   'temp_max': 30.3343,
#   'precip_min': 0.0003,
#   'precip_med': 0.0662,
#   'precip_max': 0.3228,
#   'precip_tot': 0.5294,
#   'pressao_min': 0.9964,
#   'pressao_med': 0.9988,
#   'pressao_max': 1.0001,
#   'umid_min': 71.9706,
#   'umid_med': 86.3932,
#   'umid_max': 94.9756},
#  {'date': '2024-06-07',
#   'geocodigo': 1302603,
#   'temp_min': 24.9914,
#   'temp_med': 27.6401,
#   'temp_max': 30.6975,
#   'precip_min': 0.0,
#   'precip_med': 0.1204,
#   'precip_max': 0.6797,
#   'precip_tot': 0.963,
#   'pressao_min': 0.9979,
#   'pressao_med': 0.9994,
#   'pressao_max': 1.0011,
#   'umid_min': 69.5402,
#   'umid_med': 84.9322,
#   'umid_max': 96.4407},
#  {'date': '2024-06-08',
#   'geocodigo': 1302603,
#   'temp_min': 24.789,
#   'temp_med': 27.6837,
#   'temp_max': 30.5164,
#   'precip_min': 0.0,
#   'precip_med': 0.0183,
#   'precip_max': 0.1268,
#   'precip_tot': 0.1463,
#   'pressao_min': 0.9987,
#   'pressao_med': 1.0003,
#   'pressao_max': 1.0025,
#   'umid_min': 69.1279,
#   'umid_med': 83.0843,
#   'umid_max': 95.1801},
#  {'date': '2024-06-09',
#   'geocodigo': 1302603,
#   'temp_min': 25.2356,
#   'temp_med': 27.4129,
#   'temp_max': 31.2769,
#   'precip_min': 0.0,
#   'precip_med': 0.69,
#   'precip_max': 4.3156,
#   'precip_tot': 5.5199,
#   'pressao_min': 0.9971,
#   'pressao_med': 0.9998,
#   'pressao_max': 1.0019,
#   'umid_min': 67.9912,
#   'umid_med': 84.4133,
#   'umid_max': 94.0327},
#  {'date': '2024-06-10',
#   'geocodigo': 1302603,
#   'temp_min': 24.7632,
#   'temp_med': 27.1747,
#   'temp_max': 30.4878,
#   'precip_min': 0.0,
#   'precip_med': 0.2502,
#   'precip_max': 1.0472,
#   'precip_tot': 2.0018,
#   'pressao_min': 0.9967,
#   'pressao_med': 0.999,
#   'pressao_max': 1.0006,
#   'umid_min': 70.7714,
#   'umid_med': 84.7452,
#   'umid_max': 94.3377},
#  {'date': '2024-06-11',
#   'geocodigo': 1302603,
#   'temp_min': 24.9671,
#   'temp_med': 27.2546,
#   'temp_max': 30.7352,
#   'precip_min': 0.0,
#   'precip_med': 0.1396,
#   'precip_max': 0.6736,
#   'precip_tot': 1.1165,
#   'pressao_min': 0.9971,
#   'pressao_med': 0.9991,
#   'pressao_max': 1.0011,
#   'umid_min': 70.4863,
#   'umid_med': 85.1433,
#   'umid_max': 95.1891},
#  {'date': '2024-06-12',
#   'geocodigo': 1302603,
#   'temp_min': 25.3778,
#   'temp_med': 27.5329,
#   'temp_max': 31.009,
#   'precip_min': 0.0,
#   'precip_med': 0.2428,
#   'precip_max': 1.0072,
#   'precip_tot': 1.9421,
#   'pressao_min': 0.9967,
#   'pressao_med': 0.9987,
#   'pressao_max': 1.0001,
#   'umid_min': 69.6666,
#   'umid_med': 83.2035,
#   'umid_max': 91.0256},
#  {'date': '2024-06-13',
#   'geocodigo': 1302603,
#   'temp_min': 24.7656,
#   'temp_med': 27.4063,
#   'temp_max': 31.3995,
#   'precip_min': 0.0129,
#   'precip_med': 0.4198,
#   'precip_max': 2.256,
#   'precip_tot': 3.3583,
#   'pressao_min': 0.996,
#   'pressao_med': 0.9983,
#   'pressao_max': 0.9999,
#   'umid_min': 69.517,
#   'umid_med': 83.9666,
#   'umid_max': 93.661},
#  {'date': '2024-06-14',
#   'geocodigo': 1302603,
#   'temp_min': 24.8382,
#   'temp_med': 28.2036,
#   'temp_max': 32.014,
#   'precip_min': 0.0,
#   'precip_med': 0.0128,
#   'precip_max': 0.0853,
#   'precip_tot': 0.1021,
#   'pressao_min': 0.996,
#   'pressao_med': 0.9984,
#   'pressao_max': 1.0,
#   'umid_min': 59.5525,
#   'umid_med': 79.0759,
#   'umid_max': 93.7939},
#  {'date': '2024-06-15',
#   'geocodigo': 1302603,
#   'temp_min': 25.4474,
#   'temp_med': 28.487,
#   'temp_max': 31.9367,
#   'precip_min': 0.0,
#   'precip_med': 0.0482,
#   'precip_max': 0.2527,
#   'precip_tot': 0.3859,
#   'pressao_min': 0.9975,
#   'pressao_med': 0.9988,
#   'pressao_max': 1.0006,
#   'umid_min': 63.1965,
#   'umid_med': 77.6322,
#   'umid_max': 89.2884},
#  {'date': '2024-06-16',
#   'geocodigo': 1302603,
#   'temp_min': 24.9301,
#   'temp_med': 28.4558,
#   'temp_max': 32.0071,
#   'precip_min': 0.0,
#   'precip_med': 0.0252,
#   'precip_max': 0.1407,
#   'precip_tot': 0.2017,
#   'pressao_min': 0.9965,
#   'pressao_med': 0.9984,
#   'pressao_max': 1.0,
#   'umid_min': 60.2612,
#   'umid_med': 77.8279,
#   'umid_max': 91.5296},
#  {'date': '2024-06-17',
#   'geocodigo': 1302603,
#   'temp_min': 25.1261,
#   'temp_med': 28.5866,
#   'temp_max': 32.4253,
#   'precip_min': 0.0,
#   'precip_med': 0.0196,
#   'precip_max': 0.1074,
#   'precip_tot': 0.1565,
#   'pressao_min': 0.9948,
#   'pressao_med': 0.9975,
#   'pressao_max': 0.9989,
#   'umid_min': 58.8136,
#   'umid_med': 77.7223,
#   'umid_max': 91.8218},
#  {'date': '2024-06-18',
#   'geocodigo': 1302603,
#   'temp_min': 25.2026,
#   'temp_med': 27.1688,
#   'temp_max': 30.3061,
#   'precip_min': 0.0001,
#   'precip_med': 0.185,
#   'precip_max': 0.7255,
#   'precip_tot': 1.4799,
#   'pressao_min': 0.9948,
#   'pressao_med': 0.9967,
#   'pressao_max': 0.9986,
#   'umid_min': 71.8025,
#   'umid_med': 84.7961,
#   'umid_max': 95.7314},
#  {'date': '2024-06-19',
#   'geocodigo': 1302603,
#   'temp_min': 25.0518,
#   'temp_med': 27.7134,
#   'temp_max': 31.9907,
#   'precip_min': 0.0,
#   'precip_med': 0.0103,
#   'precip_max': 0.0427,
#   'precip_tot': 0.0824,
#   'pressao_min': 0.9946,
#   'pressao_med': 0.9971,
#   'pressao_max': 0.9992,
#   'umid_min': 61.697,
#   'umid_med': 80.9482,
#   'umid_max': 92.2195},
#  {'date': '2024-06-20',
#   'geocodigo': 1302603,
#   'temp_min': 25.3296,
#   'temp_med': 28.549,
#   'temp_max': 32.2954,
#   'precip_min': 0.0,
#   'precip_med': 0.0058,
#   'precip_max': 0.0242,
#   'precip_tot': 0.0462,
#   'pressao_min': 0.9949,
#   'pressao_med': 0.9969,
#   'pressao_max': 0.9987,
#   'umid_min': 59.1828,
#   'umid_med': 78.1525,
#   'umid_max': 91.6162},
#  {'date': '2024-06-21',
#   'geocodigo': 1302603,
#   'temp_min': 25.463,
#   'temp_med': 28.2698,
#   'temp_max': 31.2343,
#   'precip_min': 0.0,
#   'precip_med': 0.0431,
#   'precip_max': 0.3182,
#   'precip_tot': 0.3445,
#   'pressao_min': 0.9953,
#   'pressao_med': 0.9974,
#   'pressao_max': 0.9989,
#   'umid_min': 65.1123,
#   'umid_med': 78.6814,
#   'umid_max': 90.3719},
#  {'date': '2024-06-22',
#   'geocodigo': 1302603,
#   'temp_min': 25.1439,
#   'temp_med': 28.5148,
#   'temp_max': 32.5119,
#   'precip_min': 0.0,
#   'precip_med': 0.0472,
#   'precip_max': 0.2394,
#   'precip_tot': 0.3778,
#   'pressao_min': 0.9953,
#   'pressao_med': 0.9978,
#   'pressao_max': 0.9996,
#   'umid_min': 56.9369,
#   'umid_med': 77.7691,
#   'umid_max': 92.6126},
#  {'date': '2024-06-23',
#   'geocodigo': 1302603,
#   'temp_min': 25.5004,
#   'temp_med': 27.9057,
#   'temp_max': 31.1839,
#   'precip_min': 0.0,
#   'precip_med': 0.1976,
#   'precip_max': 1.2326,
#   'precip_tot': 1.581,
#   'pressao_min': 0.9968,
#   'pressao_med': 0.9981,
#   'pressao_max': 1.0,
#   'umid_min': 65.1088,
#   'umid_med': 78.6218,
#   'umid_max': 89.1053},
#  {'date': '2024-06-24',
#   'geocodigo': 1302603,
#   'temp_min': 24.3229,
#   'temp_med': 27.0146,
#   'temp_max': 30.0401,
#   'precip_min': 0.0,
#   'precip_med': 0.0402,
#   'precip_max': 0.1381,
#   'precip_tot': 0.322,
#   'pressao_min': 0.9973,
#   'pressao_med': 0.9986,
#   'pressao_max': 1.0003,
#   'umid_min': 68.7151,
#   'umid_med': 82.4697,
#   'umid_max': 93.1622},
#  {'date': '2024-06-25',
#   'geocodigo': 1302603,
#   'temp_min': 24.9157,
#   'temp_med': 27.6515,
#   'temp_max': 31.7605,
#   'precip_min': 0.0,
#   'precip_med': 0.0126,
#   'precip_max': 0.0794,
#   'precip_tot': 0.1011,
#   'pressao_min': 0.9973,
#   'pressao_med': 0.9992,
#   'pressao_max': 1.0011,
#   'umid_min': 61.7951,
#   'umid_med': 82.3032,
#   'umid_max': 94.6902},
#  {'date': '2024-06-26',
#   'geocodigo': 1302603,
#   'temp_min': 25.2838,
#   'temp_med': 28.3481,
#   'temp_max': 32.2628,
#   'precip_min': 0.0,
#   'precip_med': 0.0229,
#   'precip_max': 0.1153,
#   'precip_tot': 0.1829,
#   'pressao_min': 0.9971,
#   'pressao_med': 0.9997,
#   'pressao_max': 1.0012,
#   'umid_min': 58.1456,
#   'umid_med': 75.8623,
#   'umid_max': 87.413},
#  {'date': '2024-06-27',
#   'geocodigo': 1302603,
#   'temp_min': 25.3018,
#   'temp_med': 27.9666,
#   'temp_max': 31.2387,
#   'precip_min': 0.0,
#   'precip_med': 0.0446,
#   'precip_max': 0.1564,
#   'precip_tot': 0.3572,
#   'pressao_min': 0.9957,
#   'pressao_med': 0.9983,
#   'pressao_max': 0.9996,
#   'umid_min': 66.0516,
#   'umid_med': 80.3845,
#   'umid_max': 92.5072},
#  {'date': '2024-06-28',
#   'geocodigo': 1302603,
#   'temp_min': 24.4827,
#   'temp_med': 27.2482,
#   'temp_max': 31.1961,
#   'precip_min': 0.0005,
#   'precip_med': 0.0691,
#   'precip_max': 0.3393,
#   'precip_tot': 0.5525,
#   'pressao_min': 0.997,
#   'pressao_med': 0.998,
#   'pressao_max': 0.9996,
#   'umid_min': 66.2299,
#   'umid_med': 82.3623,
#   'umid_max': 92.7385},
#  {'date': '2024-06-29',
#   'geocodigo': 1302603,
#   'temp_min': 24.8427,
#   'temp_med': 28.2995,
#   'temp_max': 32.1391,
#   'precip_min': 0.0,
#   'precip_med': 0.068,
#   'precip_max': 0.3328,
#   'precip_tot': 0.5441,
#   'pressao_min': 0.9963,
#   'pressao_med': 0.9992,
#   'pressao_max': 1.001,
#   'umid_min': 58.2527,
#   'umid_med': 77.6249,
#   'umid_max': 92.7871},
#  {'date': '2024-06-30',
#   'geocodigo': 1302603,
#   'temp_min': 25.5688,
#   'temp_med': 28.7585,
#   'temp_max': 32.2919,
#   'precip_min': 0.0,
#   'precip_med': 0.0214,
#   'precip_max': 0.1262,
#   'precip_tot': 0.1712,
#   'pressao_min': 0.9954,
#   'pressao_med': 0.9984,
#   'pressao_max': 1.0001,
#   'umid_min': 59.8527,
#   'umid_med': 77.2049,
#   'umid_max': 90.2632},
#  {'date': '2024-07-01',
#   'geocodigo': 1302603,
#   'temp_min': 25.9307,
#   'temp_med': 28.3825,
#   'temp_max': 31.4734,
#   'precip_min': 0.0,
#   'precip_med': 0.0086,
#   'precip_max': 0.0462,
#   'precip_tot': 0.0688,
#   'pressao_min': 0.9958,
#   'pressao_med': 0.9982,
#   'pressao_max': 1.0,
#   'umid_min': 65.2541,
#   'umid_med': 79.4904,
#   'umid_max': 92.4352},
#  {'date': '2024-07-02',
#   'geocodigo': 1302603,
#   'temp_min': 26.5632,
#   'temp_med': 28.422,
#   'temp_max': 30.8616,
#   'precip_min': 0.0,
#   'precip_med': 0.0223,
#   'precip_max': 0.1289,
#   'precip_tot': 0.1788,
#   'pressao_min': 0.9958,
#   'pressao_med': 0.998,
#   'pressao_max': 0.9996,
#   'umid_min': 66.3948,
#   'umid_med': 78.0097,
#   'umid_max': 86.5022},
#  {'date': '2024-07-03',
#   'geocodigo': 1302603,
#   'temp_min': 25.1948,
#   'temp_med': 27.5659,
#   'temp_max': 31.5172,
#   'precip_min': 0.0029,
#   'precip_med': 0.0326,
#   'precip_max': 0.1432,
#   'precip_tot': 0.2606,
#   'pressao_min': 0.995,
#   'pressao_med': 0.9976,
#   'pressao_max': 0.9993,
#   'umid_min': 62.4257,
#   'umid_med': 80.9148,
#   'umid_max': 93.9436},
#  {'date': '2024-07-04',
#   'geocodigo': 1302603,
#   'temp_min': 25.3295,
#   'temp_med': 28.3944,
#   'temp_max': 32.4152,
#   'precip_min': 0.0,
#   'precip_med': 0.007,
#   'precip_max': 0.0215,
#   'precip_tot': 0.0563,
#   'pressao_min': 0.9945,
#   'pressao_med': 0.997,
#   'pressao_max': 0.9986,
#   'umid_min': 58.8479,
#   'umid_med': 78.8422,
#   'umid_max': 94.9615},
#  {'date': '2024-07-05',
#   'geocodigo': 1302603,
#   'temp_min': 25.4428,
#   'temp_med': 28.4644,
#   'temp_max': 32.6915,
#   'precip_min': 0.0,
#   'precip_med': 0.0036,
#   'precip_max': 0.0144,
#   'precip_tot': 0.0286,
#   'pressao_min': 0.9965,
#   'pressao_med': 0.9978,
#   'pressao_max': 0.9996,
#   'umid_min': 57.5958,
#   'umid_med': 75.4331,
#   'umid_max': 87.5585},
#  {'date': '2024-07-06',
#   'geocodigo': 1302603,
#   'temp_min': 25.2714,
#   'temp_med': 28.7559,
#   'temp_max': 32.918,
#   'precip_min': 0.0,
#   'precip_med': 0.0119,
#   'precip_max': 0.0525,
#   'precip_tot': 0.0954,
#   'pressao_min': 0.9974,
#   'pressao_med': 0.9992,
#   'pressao_max': 1.0008,
#   'umid_min': 55.8268,
#   'umid_med': 76.3899,
#   'umid_max': 91.4583},
#  {'date': '2024-07-07',
#   'geocodigo': 1302603,
#   'temp_min': 26.0652,
#   'temp_med': 28.9675,
#   'temp_max': 32.4264,
#   'precip_min': 0.0,
#   'precip_med': 0.0006,
#   'precip_max': 0.0033,
#   'precip_tot': 0.0044,
#   'pressao_min': 0.9976,
#   'pressao_med': 0.9995,
#   'pressao_max': 1.0009,
#   'umid_min': 55.2732,
#   'umid_med': 71.9626,
#   'umid_max': 84.3779},
#  {'date': '2024-07-08',
#   'geocodigo': 1302603,
#   'temp_min': 25.112,
#   'temp_med': 28.8798,
#   'temp_max': 32.8994,
#   'precip_min': 0.0,
#   'precip_med': 0.0098,
#   'precip_max': 0.061,
#   'precip_tot': 0.0782,
#   'pressao_min': 0.9962,
#   'pressao_med': 0.9992,
#   'pressao_max': 1.0006,
#   'umid_min': 50.3032,
#   'umid_med': 71.6915,
#   'umid_max': 88.7574},
#  {'date': '2024-07-09',
#   'geocodigo': 1302603,
#   'temp_min': 25.3768,
#   'temp_med': 28.915,
#   'temp_max': 33.0043,
#   'precip_min': 0.0,
#   'precip_med': 0.0122,
#   'precip_max': 0.0781,
#   'precip_tot': 0.0975,
#   'pressao_min': 0.9951,
#   'pressao_med': 0.9978,
#   'pressao_max': 0.9994,
#   'umid_min': 53.9743,
#   'umid_med': 72.0791,
#   'umid_max': 85.3914},
#  {'date': '2024-07-10',
#   'geocodigo': 1302603,
#   'temp_min': 24.688,
#   'temp_med': 26.614,
#   'temp_max': 27.5762,
#   'precip_min': 0.0,
#   'precip_med': 0.3722,
#   'precip_max': 2.048,
#   'precip_tot': 2.9775,
#   'pressao_min': 0.9954,
#   'pressao_med': 0.9975,
#   'pressao_max': 0.9997,
#   'umid_min': 78.3448,
#   'umid_med': 84.2082,
#   'umid_max': 91.6599},
#  {'date': '2024-07-11',
#   'geocodigo': 1302603,
#   'temp_min': 23.9596,
#   'temp_med': 26.4886,
#   'temp_max': 29.7693,
#   'precip_min': 0.0,
#   'precip_med': 0.2354,
#   'precip_max': 0.7961,
#   'precip_tot': 1.8836,
#   'pressao_min': 0.9969,
#   'pressao_med': 0.9984,
#   'pressao_max': 1.0007,
#   'umid_min': 72.7113,
#   'umid_med': 85.786,
#   'umid_max': 94.9476},
#  {'date': '2024-07-12',
#   'geocodigo': 1302603,
#   'temp_min': 24.6569,
#   'temp_med': 27.9631,
#   'temp_max': 32.1073,
#   'precip_min': 0.0,
#   'precip_med': 0.0187,
#   'precip_max': 0.0701,
#   'precip_tot': 0.1494,
#   'pressao_min': 0.9982,
#   'pressao_med': 0.9998,
#   'pressao_max': 1.0016,
#   'umid_min': 60.0375,
#   'umid_med': 79.6467,
#   'umid_max': 93.5862},
#  {'date': '2024-07-13',
#   'geocodigo': 1302603,
#   'temp_min': 24.4528,
#   'temp_med': 26.4593,
#   'temp_max': 27.768,
#   'precip_min': 0.0017,
#   'precip_med': 0.4813,
#   'precip_max': 1.8092,
#   'precip_tot': 3.8504,
#   'pressao_min': 0.9992,
#   'pressao_med': 1.0008,
#   'pressao_max': 1.003,
#   'umid_min': 80.4708,
#   'umid_med': 86.132,
#   'umid_max': 92.6346},
#  {'date': '2024-07-14',
#   'geocodigo': 1302603,
#   'temp_min': 24.7359,
#   'temp_med': 26.5864,
#   'temp_max': 29.7602,
#   'precip_min': 0.0008,
#   'precip_med': 0.0443,
#   'precip_max': 0.208,
#   'precip_tot': 0.3546,
#   'pressao_min': 0.9989,
#   'pressao_med': 1.0011,
#   'pressao_max': 1.0028,
#   'umid_min': 61.4659,
#   'umid_med': 81.3025,
#   'umid_max': 92.6052},
#  {'date': '2024-07-15',
#   'geocodigo': 1302603,
#   'temp_min': 24.4486,
#   'temp_med': 27.2255,
#   'temp_max': 30.708,
#   'precip_min': 0.0,
#   'precip_med': 0.0196,
#   'precip_max': 0.0958,
#   'precip_tot': 0.1568,
#   'pressao_min': 0.9993,
#   'pressao_med': 1.0011,
#   'pressao_max': 1.0028,
#   'umid_min': 63.2624,
#   'umid_med': 78.6545,
#   'umid_max': 91.3178},
#  {'date': '2024-07-16',
#   'geocodigo': 1302603,
#   'temp_min': 25.0172,
#   'temp_med': 27.6372,
#   'temp_max': 31.1586,
#   'precip_min': 0.0,
#   'precip_med': 0.0048,
#   'precip_max': 0.0143,
#   'precip_tot': 0.0386,
#   'pressao_min': 1.0,
#   'pressao_med': 1.0015,
#   'pressao_max': 1.0032,
#   'umid_min': 55.9038,
#   'umid_med': 77.3857,
#   'umid_max': 91.4625},
#  {'date': '2024-07-17',
#   'geocodigo': 1302603,
#   'temp_min': 24.2142,
#   'temp_med': 27.4539,
#   'temp_max': 31.4981,
#   'precip_min': 0.0,
#   'precip_med': 0.0108,
#   'precip_max': 0.0604,
#   'precip_tot': 0.0861,
#   'pressao_min': 1.0003,
#   'pressao_med': 1.0021,
#   'pressao_max': 1.0037,
#   'umid_min': 58.9237,
#   'umid_med': 76.9764,
#   'umid_max': 90.3395},
#  {'date': '2024-07-18',
#   'geocodigo': 1302603,
#   'temp_min': 24.217,
#   'temp_med': 27.7953,
#   'temp_max': 32.4321,
#   'precip_min': 0.0,
#   'precip_med': 0.0,
#   'precip_max': 0.0,
#   'precip_tot': 0.0,
#   'pressao_min': 0.9987,
#   'pressao_med': 1.0011,
#   'pressao_max': 1.0025,
#   'umid_min': 50.0591,
#   'umid_med': 75.8851,
#   'umid_max': 92.6177},
#  {'date': '2024-07-19',
#   'geocodigo': 1302603,
#   'temp_min': 24.5764,
#   'temp_med': 28.2366,
#   'temp_max': 32.4374,
#   'precip_min': 0.0,
#   'precip_med': 0.0011,
#   'precip_max': 0.0088,
#   'precip_tot': 0.0088,
#   'pressao_min': 0.9988,
#   'pressao_med': 1.001,
#   'pressao_max': 1.0027,
#   'umid_min': 49.61,
#   'umid_med': 71.8158,
#   'umid_max': 87.6486},
#  {'date': '2024-07-20',
#   'geocodigo': 1302603,
#   'temp_min': 24.8453,
#   'temp_med': 28.6691,
#   'temp_max': 32.9867,
#   'precip_min': 0.0,
#   'precip_med': 0.0013,
#   'precip_max': 0.0088,
#   'precip_tot': 0.01,
#   'pressao_min': 0.9975,
#   'pressao_med': 1.0005,
#   'pressao_max': 1.0021,
#   'umid_min': 48.2074,
#   'umid_med': 69.6409,
#   'umid_max': 87.7963},
#  {'date': '2024-07-21',
#   'geocodigo': 1302603,
#   'temp_min': 25.6089,
#   'temp_med': 28.3056,
#   'temp_max': 31.5789,
#   'precip_min': 0.0,
#   'precip_med': 0.0077,
#   'precip_max': 0.0613,
#   'precip_tot': 0.0618,
#   'pressao_min': 0.9971,
#   'pressao_med': 0.9993,
#   'pressao_max': 1.0008,
#   'umid_min': 56.9262,
#   'umid_med': 73.0387,
#   'umid_max': 88.29},
#  {'date': '2024-07-22',
#   'geocodigo': 1302603,
#   'temp_min': 24.4438,
#   'temp_med': 28.2465,
#   'temp_max': 32.8172,
#   'precip_min': 0.0,
#   'precip_med': 0.0049,
#   'precip_max': 0.037,
#   'precip_tot': 0.039,
#   'pressao_min': 0.9976,
#   'pressao_med': 0.9994,
#   'pressao_max': 1.001,
#   'umid_min': 55.9897,
#   'umid_med': 75.3075,
#   'umid_max': 89.3613},
#  {'date': '2024-07-23',
#   'geocodigo': 1302603,
#   'temp_min': 25.2227,
#   'temp_med': 28.9399,
#   'temp_max': 33.4397,
#   'precip_min': 0.0,
#   'precip_med': 0.0,
#   'precip_max': 0.0,
#   'precip_tot': 0.0,
#   'pressao_min': 0.9985,
#   'pressao_med': 1.0001,
#   'pressao_max': 1.0018,
#   'umid_min': 45.7123,
#   'umid_med': 70.0739,
#   'umid_max': 88.2378},
#  {'date': '2024-07-24',
#   'geocodigo': 1302603,
#   'temp_min': 25.4461,
#   'temp_med': 29.1257,
#   'temp_max': 33.4358,
#   'precip_min': 0.0,
#   'precip_med': 0.0,
#   'precip_max': 0.0,
#   'precip_tot': 0.0,
#   'pressao_min': 0.9998,
#   'pressao_med': 1.001,
#   'pressao_max': 1.0026,
#   'umid_min': 44.9246,
#   'umid_med': 64.5673,
#   'umid_max': 78.2622},
#  {'date': '2024-07-25',
#   'geocodigo': 1302603,
#   'temp_min': 25.7442,
#   'temp_med': 28.7053,
#   'temp_max': 32.6648,
#   'precip_min': 0.0,
#   'precip_med': 0.0005,
#   'precip_max': 0.0024,
#   'precip_tot': 0.0043,
#   'pressao_min': 0.9982,
#   'pressao_med': 1.0012,
#   'pressao_max': 1.003,
#   'umid_min': 51.8399,
#   'umid_med': 70.4542,
#   'umid_max': 82.7198},
#  {'date': '2024-07-26',
#   'geocodigo': 1302603,
#   'temp_min': 24.771,
#   'temp_med': 28.0614,
#   'temp_max': 32.3672,
#   'precip_min': 0.0,
#   'precip_med': 0.0223,
#   'precip_max': 0.1417,
#   'precip_tot': 0.1781,
#   'pressao_min': 0.9966,
#   'pressao_med': 0.9995,
#   'pressao_max': 1.0008,
#   'umid_min': 56.9317,
#   'umid_med': 76.3205,
#   'umid_max': 89.8688},
#  {'date': '2024-07-27',
#   'geocodigo': 1302603,
#   'temp_min': 25.7216,
#   'temp_med': 29.0631,
#   'temp_max': 33.2534,
#   'precip_min': 0.0,
#   'precip_med': 0.057,
#   'precip_max': 0.351,
#   'precip_tot': 0.456,
#   'pressao_min': 0.9976,
#   'pressao_med': 0.9989,
#   'pressao_max': 1.0004,
#   'umid_min': 50.949,
#   'umid_med': 71.4454,
#   'umid_max': 85.0543},
#  {'date': '2024-07-28',
#   'geocodigo': 1302603,
#   'temp_min': 25.9755,
#   'temp_med': 29.3767,
#   'temp_max': 33.5662,
#   'precip_min': 0.0,
#   'precip_med': 0.0008,
#   'precip_max': 0.0045,
#   'precip_tot': 0.0062,
#   'pressao_min': 0.998,
#   'pressao_med': 0.9997,
#   'pressao_max': 1.0013,
#   'umid_min': 48.4212,
#   'umid_med': 68.4074,
#   'umid_max': 81.9884},
#  {'date': '2024-07-29',
#   'geocodigo': 1302603,
#   'temp_min': 25.7959,
#   'temp_med': 29.6698,
#   'temp_max': 33.9127,
#   'precip_min': 0.0,
#   'precip_med': 0.0077,
#   'precip_max': 0.0591,
#   'precip_tot': 0.0612,
#   'pressao_min': 0.9983,
#   'pressao_med': 1.0002,
#   'pressao_max': 1.0019,
#   'umid_min': 45.2668,
#   'umid_med': 65.9535,
#   'umid_max': 81.6191},
#  {'date': '2024-07-30',
#   'geocodigo': 1302603,
#   'temp_min': 26.4797,
#   'temp_med': 29.7361,
#   'temp_max': 33.7654,
#   'precip_min': 0.0,
#   'precip_med': 0.0019,
#   'precip_max': 0.015,
#   'precip_tot': 0.015,
#   'pressao_min': 0.9972,
#   'pressao_med': 0.9998,
#   'pressao_max': 1.0016,
#   'umid_min': 46.1509,
#   'umid_med': 65.721,
#   'umid_max': 78.7165},
#  {'date': '2024-07-31',
#   'geocodigo': 1302603,
#   'temp_min': 26.5461,
#   'temp_med': 29.8932,
#   'temp_max': 34.4409,
#   'precip_min': 0.0,
#   'precip_med': 0.0,
#   'precip_max': 0.0003,
#   'precip_tot': 0.0003,
#   'pressao_min': 0.9979,
#   'pressao_med': 0.9995,
#   'pressao_max': 1.0013,
#   'umid_min': 42.3204,
#   'umid_med': 63.1856,
#   'umid_max': 78.2271},
#  {'date': '2024-08-01',
#   'geocodigo': 1302603,
#   'temp_min': 25.7321,
#   'temp_med': 29.3878,
#   'temp_max': 33.75,
#   'precip_min': 0.0,
#   'precip_med': 0.0001,
#   'precip_max': 0.001,
#   'precip_tot': 0.001,
#   'pressao_min': 0.9973,
#   'pressao_med': 0.9995,
#   'pressao_max': 1.0013,
#   'umid_min': 46.0293,
#   'umid_med': 65.3964,
#   'umid_max': 80.633},
#  {'date': '2024-08-02',
#   'geocodigo': 1302603,
#   'temp_min': 25.8511,
#   'temp_med': 29.14,
#   'temp_max': 32.8305,
#   'precip_min': 0.0,
#   'precip_med': 0.0137,
#   'precip_max': 0.0988,
#   'precip_tot': 0.1094,
#   'pressao_min': 0.9965,
#   'pressao_med': 0.9992,
#   'pressao_max': 1.0007,
#   'umid_min': 53.0358,
#   'umid_med': 69.0937,
#   'umid_max': 82.34},
#  {'date': '2024-08-03',
#   'geocodigo': 1302603,
#   'temp_min': 25.5466,
#   'temp_med': 28.5555,
#   'temp_max': 32.7188,
#   'precip_min': 0.0,
#   'precip_med': 0.0352,
#   'precip_max': 0.1405,
#   'precip_tot': 0.2818,
#   'pressao_min': 0.9954,
#   'pressao_med': 0.9986,
#   'pressao_max': 1.0006,
#   'umid_min': 58.0575,
#   'umid_med': 73.7473,
#   'umid_max': 84.125},
#  {'date': '2024-08-04',
#   'geocodigo': 1302603,
#   'temp_min': 25.6372,
#   'temp_med': 29.2059,
#   'temp_max': 33.4515,
#   'precip_min': 0.0,
#   'precip_med': 0.0086,
#   'precip_max': 0.0651,
#   'precip_tot': 0.0691,
#   'pressao_min': 0.9958,
#   'pressao_med': 0.9983,
#   'pressao_max': 1.0,
#   'umid_min': 49.5779,
#   'umid_med': 72.7535,
#   'umid_max': 92.6603},
#  {'date': '2024-08-05',
#   'geocodigo': 1302603,
#   'temp_min': 25.5522,
#   'temp_med': 29.4141,
#   'temp_max': 33.8493,
#   'precip_min': 0.0,
#   'precip_med': 0.0,
#   'precip_max': 0.0,
#   'precip_tot': 0.0,
#   'pressao_min': 0.9961,
#   'pressao_med': 0.9984,
#   'pressao_max': 1.0003,
#   'umid_min': 42.2204,
#   'umid_med': 64.9402,
#   'umid_max': 80.8459}]

# %%
df = pd.DataFrame(items)
df
# Out:
#           date  geocodigo  temp_min  temp_med  temp_max  precip_min  \
# 0   2024-06-01    1302603   24.2908   25.6076   26.6718      0.0044
# 1   2024-06-02    1302603   24.3025   26.9596   31.0277      0.0000
# 2   2024-06-03    1302603   25.1499   26.5381   28.5926      0.0000
# 3   2024-06-04    1302603   24.0487   27.2753   31.6334      0.0000
# 4   2024-06-05    1302603   25.5905   27.9201   31.3350      0.0000
# ..         ...        ...       ...       ...       ...         ...
# 61  2024-08-01    1302603   25.7321   29.3878   33.7500      0.0000
# 62  2024-08-02    1302603   25.8511   29.1400   32.8305      0.0000
# 63  2024-08-03    1302603   25.5466   28.5555   32.7188      0.0000
# 64  2024-08-04    1302603   25.6372   29.2059   33.4515      0.0000
# 65  2024-08-05    1302603   25.5522   29.4141   33.8493      0.0000
#
#     precip_med  precip_max  precip_tot  pressao_min  pressao_med  pressao_max  \
# 0       0.3055      1.0001      2.4442       0.9985       1.0001       1.0018
# 1       0.0925      0.3632      0.7400       0.9969       0.9995       1.0009
# 2       0.0789      0.3546      0.6315       0.9987       1.0003       1.0021
# 3       0.0118      0.0384      0.0943       0.9970       0.9993       1.0008
# 4       0.0631      0.3092      0.5049       0.9967       0.9988       1.0002
# ..         ...         ...         ...          ...          ...          ...
# 61      0.0001      0.0010      0.0010       0.9973       0.9995       1.0013
# 62      0.0137      0.0988      0.1094       0.9965       0.9992       1.0007
# 63      0.0352      0.1405      0.2818       0.9954       0.9986       1.0006
# 64      0.0086      0.0651      0.0691       0.9958       0.9983       1.0000
# 65      0.0000      0.0000      0.0000       0.9961       0.9984       1.0003
#
#     umid_min  umid_med  umid_max
# 0    86.1346   91.5237   95.9031
# 1    67.6306   85.9284   97.0995
# 2    79.6610   88.6693   95.0063
# 3    65.4224   85.5136   97.1420
# 4    66.8854   82.6499   92.8523
# ..       ...       ...       ...
# 61   46.0293   65.3964   80.6330
# 62   53.0358   69.0937   82.3400
# 63   58.0575   73.7473   84.1250
# 64   49.5779   72.7535   92.6603
# 65   42.2204   64.9402   80.8459
#
# [66 rows x 15 columns]

# %%
page = 1 # total amount of pages is returned in the request
per_page = 100
pagination = f"?page={page}&per_page={per_page}&"
filters = "start=%s&end=%s" % ("2004-01-01", "2008-12-31")

resp = requests.get(climate_api + pagination + filters)

# Or you can add a geocode to the filters
geocode = 1302603
resp = requests.get(
    climate_api + 
    pagination + 
    filters +
    f"&geocode={geocode}"
)

items = resp.json()["items"] # JSON data in dict format
#total_items = resp.json()["total_items"] # JSON data in dict format
resp.json()["pagination"] # Pagination*
# Out:
# {'items': 100,
#  'total_items': 1706,
#  'page': 1,
#  'total_pages': 18,
#  'per_page': 100}

# %%
items
# Out:
# [{'date': '2004-01-01',
#   'geocodigo': 1302603,
#   'temp_min': 24.7052,
#   'temp_med': 26.7748,
#   'temp_max': 30.5519,
#   'precip_min': 0.0,
#   'precip_med': 0.7406,
#   'precip_max': 3.0196,
#   'precip_tot': 5.9251,
#   'pressao_min': 0.9951,
#   'pressao_med': 0.998,
#   'pressao_max': 1.0012,
#   'umid_min': 75.0331,
#   'umid_med': 87.1228,
#   'umid_max': 94.9243},
#  {'date': '2004-01-02',
#   'geocodigo': 1302603,
#   'temp_min': 24.585,
#   'temp_med': 26.8201,
#   'temp_max': 30.1501,
#   'precip_min': 0.0212,
#   'precip_med': 0.7749,
#   'precip_max': 3.479,
#   'precip_tot': 6.1993,
#   'pressao_min': 0.9937,
#   'pressao_med': 0.9971,
#   'pressao_max': 0.999,
#   'umid_min': 74.2346,
#   'umid_med': 86.2345,
#   'umid_max': 95.9302},
#  {'date': '2004-01-03',
#   'geocodigo': 1302603,
#   'temp_min': 24.2967,
#   'temp_med': 26.216,
#   'temp_max': 28.7951,
#   'precip_min': 0.0028,
#   'precip_med': 0.541,
#   'precip_max': 1.0341,
#   'precip_tot': 4.3277,
#   'pressao_min': 0.9933,
#   'pressao_med': 0.9962,
#   'pressao_max': 0.9981,
#   'umid_min': 80.7129,
#   'umid_med': 89.0086,
#   'umid_max': 93.7411},
#  {'date': '2004-01-04',
#   'geocodigo': 1302603,
#   'temp_min': 24.4803,
#   'temp_med': 26.0561,
#   'temp_max': 28.5809,
#   'precip_min': 0.0006,
#   'precip_med': 0.3706,
#   'precip_max': 1.8163,
#   'precip_tot': 2.9649,
#   'pressao_min': 0.9925,
#   'pressao_med': 0.9951,
#   'pressao_max': 0.997,
#   'umid_min': 76.6341,
#   'umid_med': 88.7608,
#   'umid_max': 94.3893},
#  {'date': '2004-01-05',
#   'geocodigo': 1302603,
#   'temp_min': 24.1931,
#   'temp_med': 25.6888,
#   'temp_max': 28.6974,
#   'precip_min': 0.0647,
#   'precip_med': 0.8415,
#   'precip_max': 2.1096,
#   'precip_tot': 6.7318,
#   'pressao_min': 0.9938,
#   'pressao_med': 0.9955,
#   'pressao_max': 0.9973,
#   'umid_min': 80.777,
#   'umid_med': 90.8974,
#   'umid_max': 94.9595},
#  {'date': '2004-01-06',
#   'geocodigo': 1302603,
#   'temp_min': 24.7316,
#   'temp_med': 26.2201,
#   'temp_max': 28.836,
#   'precip_min': 0.0228,
#   'precip_med': 0.9221,
#   'precip_max': 3.6606,
#   'precip_tot': 7.3766,
#   'pressao_min': 0.9938,
#   'pressao_med': 0.9959,
#   'pressao_max': 0.9979,
#   'umid_min': 80.5783,
#   'umid_med': 89.5576,
#   'umid_max': 96.0178},
#  {'date': '2004-01-07',
#   'geocodigo': 1302603,
#   'temp_min': 24.5952,
#   'temp_med': 25.7902,
#   'temp_max': 28.0914,
#   'precip_min': 0.0617,
#   'precip_med': 0.522,
#   'precip_max': 1.8098,
#   'precip_tot': 4.1757,
#   'pressao_min': 0.9942,
#   'pressao_med': 0.9969,
#   'pressao_max': 0.9989,
#   'umid_min': 79.8088,
#   'umid_med': 89.8694,
#   'umid_max': 94.7613},
#  {'date': '2004-01-08',
#   'geocodigo': 1302603,
#   'temp_min': 23.9611,
#   'temp_med': 26.4302,
#   'temp_max': 31.1852,
#   'precip_min': 0.0004,
#   'precip_med': 0.4503,
#   'precip_max': 2.0244,
#   'precip_tot': 3.6023,
#   'pressao_min': 0.9941,
#   'pressao_med': 0.9968,
#   'pressao_max': 0.9989,
#   'umid_min': 72.3284,
#   'umid_med': 88.281,
#   'umid_max': 97.611},
#  {'date': '2004-01-09',
#   'geocodigo': 1302603,
#   'temp_min': 24.9973,
#   'temp_med': 26.3938,
#   'temp_max': 28.3817,
#   'precip_min': 0.2129,
#   'precip_med': 1.2755,
#   'precip_max': 2.5944,
#   'precip_tot': 10.2041,
#   'pressao_min': 0.9937,
#   'pressao_med': 0.9965,
#   'pressao_max': 0.9986,
#   'umid_min': 82.373,
#   'umid_med': 88.6162,
#   'umid_max': 94.8911},
#  {'date': '2004-01-10',
#   'geocodigo': 1302603,
#   'temp_min': 24.9614,
#   'temp_med': 26.5101,
#   'temp_max': 29.4938,
#   'precip_min': 0.0038,
#   'precip_med': 0.4401,
#   'precip_max': 1.427,
#   'precip_tot': 3.5205,
#   'pressao_min': 0.9934,
#   'pressao_med': 0.996,
#   'pressao_max': 0.998,
#   'umid_min': 74.9429,
#   'umid_med': 88.2709,
#   'umid_max': 94.7779},
#  {'date': '2004-01-11',
#   'geocodigo': 1302603,
#   'temp_min': 24.3915,
#   'temp_med': 26.8669,
#   'temp_max': 29.8512,
#   'precip_min': 0.0022,
#   'precip_med': 0.2265,
#   'precip_max': 0.9538,
#   'precip_tot': 1.8119,
#   'pressao_min': 0.9943,
#   'pressao_med': 0.9967,
#   'pressao_max': 0.9989,
#   'umid_min': 70.1738,
#   'umid_med': 87.1578,
#   'umid_max': 96.2681},
#  {'date': '2004-01-12',
#   'geocodigo': 1302603,
#   'temp_min': 25.1073,
#   'temp_med': 27.451,
#   'temp_max': 30.491,
#   'precip_min': 0.0,
#   'precip_med': 0.4679,
#   'precip_max': 2.2979,
#   'precip_tot': 3.7433,
#   'pressao_min': 0.9956,
#   'pressao_med': 0.9976,
#   'pressao_max': 0.9999,
#   'umid_min': 73.3719,
#   'umid_med': 87.2565,
#   'umid_max': 96.1244},
#  {'date': '2004-01-13',
#   'geocodigo': 1302603,
#   'temp_min': 24.9219,
#   'temp_med': 26.3104,
#   'temp_max': 27.4998,
#   'precip_min': 0.0024,
#   'precip_med': 0.5101,
#   'precip_max': 1.5913,
#   'precip_tot': 4.0811,
#   'pressao_min': 0.9951,
#   'pressao_med': 0.9976,
#   'pressao_max': 0.9998,
#   'umid_min': 85.794,
#   'umid_med': 90.5872,
#   'umid_max': 96.1679},
#  {'date': '2004-01-14',
#   'geocodigo': 1302603,
#   'temp_min': 24.5944,
#   'temp_med': 27.2827,
#   'temp_max': 31.5926,
#   'precip_min': 0.0,
#   'precip_med': 0.0419,
#   'precip_max': 0.0998,
#   'precip_tot': 0.3352,
#   'pressao_min': 0.9927,
#   'pressao_med': 0.9963,
#   'pressao_max': 0.9987,
#   'umid_min': 70.8473,
#   'umid_med': 86.8428,
#   'umid_max': 96.6097},
#  {'date': '2004-01-15',
#   'geocodigo': 1302603,
#   'temp_min': 25.9332,
#   'temp_med': 28.8582,
#   'temp_max': 32.4573,
#   'precip_min': 0.0,
#   'precip_med': 0.0789,
#   'precip_max': 0.3939,
#   'precip_tot': 0.6309,
#   'pressao_min': 0.9919,
#   'pressao_med': 0.9948,
#   'pressao_max': 0.9968,
#   'umid_min': 64.7578,
#   'umid_med': 80.1502,
#   'umid_max': 92.1607},
#  {'date': '2004-01-16',
#   'geocodigo': 1302603,
#   'temp_min': 25.5918,
#   'temp_med': 26.9869,
#   'temp_max': 28.8431,
#   'precip_min': 0.0021,
#   'precip_med': 0.3877,
#   'precip_max': 1.1268,
#   'precip_tot': 3.1014,
#   'pressao_min': 0.9938,
#   'pressao_med': 0.9956,
#   'pressao_max': 0.9984,
#   'umid_min': 82.9498,
#   'umid_med': 88.358,
#   'umid_max': 92.0625},
#  {'date': '2004-01-17',
#   'geocodigo': 1302603,
#   'temp_min': 24.6086,
#   'temp_med': 26.3933,
#   'temp_max': 29.6156,
#   'precip_min': 0.0,
#   'precip_med': 0.1474,
#   'precip_max': 0.8531,
#   'precip_tot': 1.1793,
#   'pressao_min': 0.9954,
#   'pressao_med': 0.9973,
#   'pressao_max': 0.9995,
#   'umid_min': 75.7648,
#   'umid_med': 88.4852,
#   'umid_max': 97.0733},
#  {'date': '2004-01-18',
#   'geocodigo': 1302603,
#   'temp_min': 24.2563,
#   'temp_med': 26.9217,
#   'temp_max': 30.6978,
#   'precip_min': 0.0,
#   'precip_med': 0.0969,
#   'precip_max': 0.3365,
#   'precip_tot': 0.775,
#   'pressao_min': 0.9931,
#   'pressao_med': 0.997,
#   'pressao_max': 0.9992,
#   'umid_min': 67.236,
#   'umid_med': 85.3058,
#   'umid_max': 96.3406},
#  {'date': '2004-01-19',
#   'geocodigo': 1302603,
#   'temp_min': 23.8647,
#   'temp_med': 26.9926,
#   'temp_max': 30.2003,
#   'precip_min': 0.0019,
#   'precip_med': 0.4556,
#   'precip_max': 1.8563,
#   'precip_tot': 3.645,
#   'pressao_min': 0.9939,
#   'pressao_med': 0.9963,
#   'pressao_max': 0.9978,
#   'umid_min': 69.6205,
#   'umid_med': 83.9911,
#   'umid_max': 95.6541},
#  {'date': '2004-01-20',
#   'geocodigo': 1302603,
#   'temp_min': 25.368,
#   'temp_med': 27.8759,
#   'temp_max': 31.5199,
#   'precip_min': 0.0,
#   'precip_med': 0.0399,
#   'precip_max': 0.244,
#   'precip_tot': 0.3192,
#   'pressao_min': 0.9931,
#   'pressao_med': 0.9958,
#   'pressao_max': 0.998,
#   'umid_min': 69.5268,
#   'umid_med': 84.4929,
#   'umid_max': 96.2065},
#  {'date': '2004-01-21',
#   'geocodigo': 1302603,
#   'temp_min': 26.099,
#   'temp_med': 29.0715,
#   'temp_max': 32.9935,
#   'precip_min': 0.0,
#   'precip_med': 0.0008,
#   'precip_max': 0.0063,
#   'precip_tot': 0.0068,
#   'pressao_min': 0.9921,
#   'pressao_med': 0.9954,
#   'pressao_max': 0.9977,
#   'umid_min': 58.6227,
#   'umid_med': 77.9902,
#   'umid_max': 93.786},
#  {'date': '2004-01-22',
#   'geocodigo': 1302603,
#   'temp_min': 26.5977,
#   'temp_med': 29.0411,
#   'temp_max': 33.4083,
#   'precip_min': 0.0,
#   'precip_med': 0.097,
#   'precip_max': 0.7089,
#   'precip_tot': 0.7762,
#   'pressao_min': 0.9929,
#   'pressao_med': 0.9952,
#   'pressao_max': 0.9972,
#   'umid_min': 56.4834,
#   'umid_med': 76.9864,
#   'umid_max': 90.1054},
#  {'date': '2004-01-23',
#   'geocodigo': 1302603,
#   'temp_min': 24.5964,
#   'temp_med': 27.1055,
#   'temp_max': 30.472,
#   'precip_min': 0.0,
#   'precip_med': 0.5272,
#   'precip_max': 3.6993,
#   'precip_tot': 4.2177,
#   'pressao_min': 0.9942,
#   'pressao_med': 0.9959,
#   'pressao_max': 0.9988,
#   'umid_min': 73.9247,
#   'umid_med': 85.8538,
#   'umid_max': 95.7981},
#  {'date': '2004-01-24',
#   'geocodigo': 1302603,
#   'temp_min': 24.6457,
#   'temp_med': 27.0926,
#   'temp_max': 31.1814,
#   'precip_min': 0.0,
#   'precip_med': 0.5685,
#   'precip_max': 1.7379,
#   'precip_tot': 4.5483,
#   'pressao_min': 0.9945,
#   'pressao_med': 0.9972,
#   'pressao_max': 0.9992,
#   'umid_min': 69.2757,
#   'umid_med': 84.8405,
#   'umid_max': 95.5309},
#  {'date': '2004-01-25',
#   'geocodigo': 1302603,
#   'temp_min': 24.7345,
#   'temp_med': 27.8323,
#   'temp_max': 32.2803,
#   'precip_min': 0.0,
#   'precip_med': 0.0104,
#   'precip_max': 0.048,
#   'precip_tot': 0.0831,
#   'pressao_min': 0.9934,
#   'pressao_med': 0.9962,
#   'pressao_max': 0.9979,
#   'umid_min': 62.5124,
#   'umid_med': 81.3747,
#   'umid_max': 96.311},
#  {'date': '2004-01-26',
#   'geocodigo': 1302603,
#   'temp_min': 26.3252,
#   'temp_med': 28.299,
#   'temp_max': 30.7384,
#   'precip_min': 0.0,
#   'precip_med': 0.4392,
#   'precip_max': 3.2758,
#   'precip_tot': 3.5137,
#   'pressao_min': 0.9946,
#   'pressao_med': 0.9966,
#   'pressao_max': 0.9991,
#   'umid_min': 71.5514,
#   'umid_med': 82.5376,
#   'umid_max': 94.6126},
#  {'date': '2004-01-27',
#   'geocodigo': 1302603,
#   'temp_min': 25.8556,
#   'temp_med': 28.0145,
#   'temp_max': 31.6089,
#   'precip_min': 0.0,
#   'precip_med': 0.0359,
#   'precip_max': 0.2473,
#   'precip_tot': 0.2871,
#   'pressao_min': 0.9945,
#   'pressao_med': 0.997,
#   'pressao_max': 0.9987,
#   'umid_min': 64.6452,
#   'umid_med': 83.8005,
#   'umid_max': 96.617},
#  {'date': '2004-01-28',
#   'geocodigo': 1302603,
#   'temp_min': 25.9419,
#   'temp_med': 27.2183,
#   'temp_max': 28.9161,
#   'precip_min': 0.0003,
#   'precip_med': 0.2883,
#   'precip_max': 1.0362,
#   'precip_tot': 2.3066,
#   'pressao_min': 0.9954,
#   'pressao_med': 0.9975,
#   'pressao_max': 1.0,
#   'umid_min': 77.2476,
#   'umid_med': 86.0089,
#   'umid_max': 94.8498},
#  {'date': '2004-01-29',
#   'geocodigo': 1302603,
#   'temp_min': 25.4329,
#   'temp_med': 27.2212,
#   'temp_max': 30.8543,
#   'precip_min': 0.0034,
#   'precip_med': 0.174,
#   'precip_max': 0.9447,
#   'precip_tot': 1.3924,
#   'pressao_min': 0.9941,
#   'pressao_med': 0.9968,
#   'pressao_max': 0.9987,
#   'umid_min': 63.9314,
#   'umid_med': 84.1877,
#   'umid_max': 95.179},
#  {'date': '2004-01-30',
#   'geocodigo': 1302603,
#   'temp_min': 25.2149,
#   'temp_med': 26.7366,
#   'temp_max': 29.7247,
#   'precip_min': 0.0113,
#   'precip_med': 0.1973,
#   'precip_max': 0.7392,
#   'precip_tot': 1.5787,
#   'pressao_min': 0.9942,
#   'pressao_med': 0.9964,
#   'pressao_max': 0.9987,
#   'umid_min': 75.7755,
#   'umid_med': 86.8508,
#   'umid_max': 93.8219},
#  {'date': '2004-01-31',
#   'geocodigo': 1302603,
#   'temp_min': 24.6403,
#   'temp_med': 27.4659,
#   'temp_max': 32.2105,
#   'precip_min': 0.0,
#   'precip_med': 0.0211,
#   'precip_max': 0.078,
#   'precip_tot': 0.1686,
#   'pressao_min': 0.9931,
#   'pressao_med': 0.9965,
#   'pressao_max': 0.9983,
#   'umid_min': 64.3483,
#   'umid_med': 82.685,
#   'umid_max': 93.6508},
#  {'date': '2004-02-01',
#   'geocodigo': 1302603,
#   'temp_min': 26.1172,
#   'temp_med': 28.0312,
#   'temp_max': 29.9426,
#   'precip_min': 0.0,
#   'precip_med': 0.8967,
#   'precip_max': 3.7482,
#   'precip_tot': 7.1738,
#   'pressao_min': 0.9948,
#   'pressao_med': 0.9973,
#   'pressao_max': 0.9998,
#   'umid_min': 75.5704,
#   'umid_med': 82.2459,
#   'umid_max': 87.633},
#  {'date': '2004-02-02',
#   'geocodigo': 1302603,
#   'temp_min': 25.4293,
#   'temp_med': 27.0208,
#   'temp_max': 29.4244,
#   'precip_min': 0.0001,
#   'precip_med': 0.2722,
#   'precip_max': 1.3662,
#   'precip_tot': 2.1778,
#   'pressao_min': 0.9931,
#   'pressao_med': 0.9969,
#   'pressao_max': 0.9992,
#   'umid_min': 76.4988,
#   'umid_med': 86.3315,
#   'umid_max': 94.052},
#  {'date': '2004-02-03',
#   'geocodigo': 1302603,
#   'temp_min': 24.9011,
#   'temp_med': 26.6523,
#   'temp_max': 28.9675,
#   'precip_min': 0.045,
#   'precip_med': 0.6425,
#   'precip_max': 2.3623,
#   'precip_tot': 5.1404,
#   'pressao_min': 0.9928,
#   'pressao_med': 0.9962,
#   'pressao_max': 0.9987,
#   'umid_min': 76.1973,
#   'umid_med': 87.5199,
#   'umid_max': 94.7422},
#  {'date': '2004-02-04',
#   'geocodigo': 1302603,
#   'temp_min': 25.4166,
#   'temp_med': 26.3756,
#   'temp_max': 28.5091,
#   'precip_min': 0.0132,
#   'precip_med': 0.7583,
#   'precip_max': 3.6727,
#   'precip_tot': 6.0667,
#   'pressao_min': 0.9944,
#   'pressao_med': 0.9965,
#   'pressao_max': 0.9992,
#   'umid_min': 81.6587,
#   'umid_med': 89.931,
#   'umid_max': 94.132},
#  {'date': '2004-02-05',
#   'geocodigo': 1302603,
#   'temp_min': 23.8606,
#   'temp_med': 26.1172,
#   'temp_max': 29.2596,
#   'precip_min': 0.0007,
#   'precip_med': 0.4002,
#   'precip_max': 2.022,
#   'precip_tot': 3.2015,
#   'pressao_min': 0.9941,
#   'pressao_med': 0.9973,
#   'pressao_max': 0.9995,
#   'umid_min': 72.0511,
#   'umid_med': 85.0631,
#   'umid_max': 93.4806},
#  {'date': '2004-02-06',
#   'geocodigo': 1302603,
#   'temp_min': 24.3059,
#   'temp_med': 27.5541,
#   'temp_max': 32.2258,
#   'precip_min': 0.0,
#   'precip_med': 0.2896,
#   'precip_max': 1.811,
#   'precip_tot': 2.3166,
#   'pressao_min': 0.9933,
#   'pressao_med': 0.9967,
#   'pressao_max': 0.9988,
#   'umid_min': 62.7052,
#   'umid_med': 82.4469,
#   'umid_max': 94.4191},
#  {'date': '2004-02-07',
#   'geocodigo': 1302603,
#   'temp_min': 24.7739,
#   'temp_med': 26.894,
#   'temp_max': 29.2944,
#   'precip_min': 0.0,
#   'precip_med': 0.0558,
#   'precip_max': 0.3643,
#   'precip_tot': 0.4465,
#   'pressao_min': 0.994,
#   'pressao_med': 0.9966,
#   'pressao_max': 0.9992,
#   'umid_min': 70.0859,
#   'umid_med': 83.7014,
#   'umid_max': 96.3329},
#  {'date': '2004-02-08',
#   'geocodigo': 1302603,
#   'temp_min': 24.6126,
#   'temp_med': 26.2186,
#   'temp_max': 28.7891,
#   'precip_min': 0.0416,
#   'precip_med': 0.5304,
#   'precip_max': 1.292,
#   'precip_tot': 4.2431,
#   'pressao_min': 0.9965,
#   'pressao_med': 0.998,
#   'pressao_max': 1.0005,
#   'umid_min': 76.1469,
#   'umid_med': 87.9575,
#   'umid_max': 95.2765},
#  {'date': '2004-02-09',
#   'geocodigo': 1302603,
#   'temp_min': 23.7166,
#   'temp_med': 26.758,
#   'temp_max': 30.8657,
#   'precip_min': 0.0,
#   'precip_med': 0.022,
#   'precip_max': 0.0766,
#   'precip_tot': 0.176,
#   'pressao_min': 0.9951,
#   'pressao_med': 0.9984,
#   'pressao_max': 1.0005,
#   'umid_min': 63.4293,
#   'umid_med': 84.6597,
#   'umid_max': 97.5146},
#  {'date': '2004-02-10',
#   'geocodigo': 1302603,
#   'temp_min': 24.9692,
#   'temp_med': 28.0222,
#   'temp_max': 31.8164,
#   'precip_min': 0.0,
#   'precip_med': 0.0276,
#   'precip_max': 0.1388,
#   'precip_tot': 0.221,
#   'pressao_min': 0.9938,
#   'pressao_med': 0.9969,
#   'pressao_max': 0.9985,
#   'umid_min': 59.4375,
#   'umid_med': 79.2153,
#   'umid_max': 94.815},
#  {'date': '2004-02-11',
#   'geocodigo': 1302603,
#   'temp_min': 25.0753,
#   'temp_med': 27.6732,
#   'temp_max': 31.413,
#   'precip_min': 0.0,
#   'precip_med': 0.2304,
#   'precip_max': 0.9515,
#   'precip_tot': 1.843,
#   'pressao_min': 0.9948,
#   'pressao_med': 0.9968,
#   'pressao_max': 0.9987,
#   'umid_min': 64.082,
#   'umid_med': 80.3989,
#   'umid_max': 92.1716},
#  {'date': '2004-02-12',
#   'geocodigo': 1302603,
#   'temp_min': 24.6905,
#   'temp_med': 26.1256,
#   'temp_max': 28.1565,
#   'precip_min': 0.0,
#   'precip_med': 1.0059,
#   'precip_max': 2.7044,
#   'precip_tot': 8.0471,
#   'pressao_min': 0.9962,
#   'pressao_med': 0.9985,
#   'pressao_max': 1.0012,
#   'umid_min': 83.3008,
#   'umid_med': 89.0507,
#   'umid_max': 94.3682},
#  {'date': '2004-02-13',
#   'geocodigo': 1302603,
#   'temp_min': 24.134,
#   'temp_med': 26.0096,
#   'temp_max': 29.251,
#   'precip_min': 0.0,
#   'precip_med': 0.2939,
#   'precip_max': 0.8555,
#   'precip_tot': 2.3512,
#   'pressao_min': 0.9958,
#   'pressao_med': 0.9989,
#   'pressao_max': 1.0012,
#   'umid_min': 74.0789,
#   'umid_med': 87.2729,
#   'umid_max': 96.3673},
#  {'date': '2004-02-14',
#   'geocodigo': 1302603,
#   'temp_min': 23.55,
#   'temp_med': 25.4455,
#   'temp_max': 29.0923,
#   'precip_min': 0.0128,
#   'precip_med': 0.695,
#   'precip_max': 1.6798,
#   'precip_tot': 5.56,
#   'pressao_min': 0.9953,
#   'pressao_med': 0.9986,
#   'pressao_max': 1.0012,
#   'umid_min': 78.6544,
#   'umid_med': 90.039,
#   'umid_max': 95.3294},
#  {'date': '2004-02-15',
#   'geocodigo': 1302603,
#   'temp_min': 24.4059,
#   'temp_med': 26.0179,
#   'temp_max': 28.1944,
#   'precip_min': 0.0092,
#   'precip_med': 0.4455,
#   'precip_max': 1.4599,
#   'precip_tot': 3.5642,
#   'pressao_min': 0.9949,
#   'pressao_med': 0.9982,
#   'pressao_max': 1.0009,
#   'umid_min': 78.1622,
#   'umid_med': 89.2173,
#   'umid_max': 96.2462},
#  {'date': '2004-02-16',
#   'geocodigo': 1302603,
#   'temp_min': 23.9309,
#   'temp_med': 25.7313,
#   'temp_max': 27.7154,
#   'precip_min': 0.1379,
#   'precip_med': 0.4372,
#   'precip_max': 0.8083,
#   'precip_tot': 3.4973,
#   'pressao_min': 0.9957,
#   'pressao_med': 0.9985,
#   'pressao_max': 1.0012,
#   'umid_min': 82.2238,
#   'umid_med': 90.2958,
#   'umid_max': 95.8342},
#  {'date': '2004-02-17',
#   'geocodigo': 1302603,
#   'temp_min': 24.1257,
#   'temp_med': 25.8951,
#   'temp_max': 28.7493,
#   'precip_min': 0.0001,
#   'precip_med': 0.3061,
#   'precip_max': 2.071,
#   'precip_tot': 2.4488,
#   'pressao_min': 0.9963,
#   'pressao_med': 0.9986,
#   'pressao_max': 1.0016,
#   'umid_min': 76.9194,
#   'umid_med': 90.1166,
#   'umid_max': 97.1878},
#  {'date': '2004-02-18',
#   'geocodigo': 1302603,
#   'temp_min': 23.538,
#   'temp_med': 25.5759,
#   'temp_max': 28.4441,
#   'precip_min': 0.0001,
#   'precip_med': 0.6152,
#   'precip_max': 2.8277,
#   'precip_tot': 4.9216,
#   'pressao_min': 0.9965,
#   'pressao_med': 0.9988,
#   'pressao_max': 1.001,
#   'umid_min': 84.6291,
#   'umid_med': 91.7553,
#   'umid_max': 97.9683},
#  {'date': '2004-02-19',
#   'geocodigo': 1302603,
#   'temp_min': 23.844,
#   'temp_med': 25.34,
#   'temp_max': 27.8432,
#   'precip_min': 0.4051,
#   'precip_med': 0.8139,
#   'precip_max': 1.2326,
#   'precip_tot': 6.5115,
#   'pressao_min': 0.9957,
#   'pressao_med': 0.9984,
#   'pressao_max': 1.0005,
#   'umid_min': 82.5904,
#   'umid_med': 91.0157,
#   'umid_max': 97.679},
#  {'date': '2004-02-20',
#   'geocodigo': 1302603,
#   'temp_min': 24.273,
#   'temp_med': 26.3861,
#   'temp_max': 30.0113,
#   'precip_min': 0.0437,
#   'precip_med': 0.3901,
#   'precip_max': 0.7954,
#   'precip_tot': 3.121,
#   'pressao_min': 0.994,
#   'pressao_med': 0.997,
#   'pressao_max': 0.9991,
#   'umid_min': 73.7936,
#   'umid_med': 88.041,
#   'umid_max': 97.0527},
#  {'date': '2004-02-21',
#   'geocodigo': 1302603,
#   'temp_min': 24.9247,
#   'temp_med': 25.9435,
#   'temp_max': 27.1491,
#   'precip_min': 0.1079,
#   'precip_med': 0.394,
#   'precip_max': 0.797,
#   'precip_tot': 3.1523,
#   'pressao_min': 0.9961,
#   'pressao_med': 0.9976,
#   'pressao_max': 1.0003,
#   'umid_min': 82.7699,
#   'umid_med': 89.59,
#   'umid_max': 95.9337},
#  {'date': '2004-02-22',
#   'geocodigo': 1302603,
#   'temp_min': 23.9377,
#   'temp_med': 25.6445,
#   'temp_max': 28.6398,
#   'precip_min': 0.0306,
#   'precip_med': 0.7648,
#   'precip_max': 1.318,
#   'precip_tot': 6.1183,
#   'pressao_min': 0.9973,
#   'pressao_med': 0.9995,
#   'pressao_max': 1.0017,
#   'umid_min': 81.1524,
#   'umid_med': 90.806,
#   'umid_max': 96.1409},
#  {'date': '2004-02-23',
#   'geocodigo': 1302603,
#   'temp_min': 23.9629,
#   'temp_med': 25.7763,
#   'temp_max': 27.7364,
#   'precip_min': 0.0062,
#   'precip_med': 0.2732,
#   'precip_max': 1.2803,
#   'precip_tot': 2.1854,
#   'pressao_min': 0.9959,
#   'pressao_med': 0.9991,
#   'pressao_max': 1.0014,
#   'umid_min': 84.287,
#   'umid_med': 90.4346,
#   'umid_max': 96.1339},
#  {'date': '2004-02-24',
#   'geocodigo': 1302603,
#   'temp_min': 24.0412,
#   'temp_med': 25.4368,
#   'temp_max': 28.6792,
#   'precip_min': 0.3242,
#   'precip_med': 0.949,
#   'precip_max': 1.6386,
#   'precip_tot': 7.5923,
#   'pressao_min': 0.9949,
#   'pressao_med': 0.9978,
#   'pressao_max': 0.9999,
#   'umid_min': 78.1007,
#   'umid_med': 90.1095,
#   'umid_max': 95.3853},
#  {'date': '2004-02-25',
#   'geocodigo': 1302603,
#   'temp_min': 24.161,
#   'temp_med': 25.9176,
#   'temp_max': 28.8673,
#   'precip_min': 0.0031,
#   'precip_med': 0.5412,
#   'precip_max': 2.4259,
#   'precip_tot': 4.3298,
#   'pressao_min': 0.9953,
#   'pressao_med': 0.9974,
#   'pressao_max': 1.0,
#   'umid_min': 79.2747,
#   'umid_med': 89.1593,
#   'umid_max': 96.1186},
#  {'date': '2004-02-26',
#   'geocodigo': 1302603,
#   'temp_min': 23.8788,
#   'temp_med': 26.6262,
#   'temp_max': 30.0761,
#   'precip_min': 0.0002,
#   'precip_med': 0.0879,
#   'precip_max': 0.2748,
#   'precip_tot': 0.703,
#   'pressao_min': 0.9958,
#   'pressao_med': 0.9987,
#   'pressao_max': 1.002,
#   'umid_min': 71.11,
#   'umid_med': 85.3772,
#   'umid_max': 95.4489},
#  {'date': '2004-02-27',
#   'geocodigo': 1302603,
#   'temp_min': 24.583,
#   'temp_med': 27.0241,
#   'temp_max': 30.2775,
#   'precip_min': 0.0011,
#   'precip_med': 0.7934,
#   'precip_max': 4.2157,
#   'precip_tot': 6.3471,
#   'pressao_min': 0.9957,
#   'pressao_med': 0.9988,
#   'pressao_max': 1.0014,
#   'umid_min': 74.5743,
#   'umid_med': 86.4175,
#   'umid_max': 94.2465},
#  {'date': '2004-02-28',
#   'geocodigo': 1302603,
#   'temp_min': 24.5417,
#   'temp_med': 26.4243,
#   'temp_max': 29.7208,
#   'precip_min': 0.0066,
#   'precip_med': 1.0135,
#   'precip_max': 4.606,
#   'precip_tot': 8.1077,
#   'pressao_min': 0.9949,
#   'pressao_med': 0.9976,
#   'pressao_max': 0.9995,
#   'umid_min': 74.1995,
#   'umid_med': 87.9088,
#   'umid_max': 95.526},
#  {'date': '2004-02-29',
#   'geocodigo': 1302603,
#   'temp_min': 23.6752,
#   'temp_med': 26.1247,
#   'temp_max': 29.5897,
#   'precip_min': 0.0,
#   'precip_med': 0.3132,
#   'precip_max': 2.0471,
#   'precip_tot': 2.5053,
#   'pressao_min': 0.9945,
#   'pressao_med': 0.9971,
#   'pressao_max': 1.0003,
#   'umid_min': 71.8276,
#   'umid_med': 87.2268,
#   'umid_max': 97.0631},
#  {'date': '2004-03-01',
#   'geocodigo': 1302603,
#   'temp_min': 24.657,
#   'temp_med': 27.3124,
#   'temp_max': 31.8089,
#   'precip_min': 0.0,
#   'precip_med': 0.0386,
#   'precip_max': 0.2354,
#   'precip_tot': 0.3085,
#   'pressao_min': 0.9944,
#   'pressao_med': 0.9972,
#   'pressao_max': 0.9999,
#   'umid_min': 65.1026,
#   'umid_med': 84.9376,
#   'umid_max': 96.9085},
#  {'date': '2004-03-02',
#   'geocodigo': 1302603,
#   'temp_min': 25.0531,
#   'temp_med': 26.8291,
#   'temp_max': 29.5756,
#   'precip_min': 0.0,
#   'precip_med': 0.4631,
#   'precip_max': 3.1115,
#   'precip_tot': 3.7045,
#   'pressao_min': 0.9953,
#   'pressao_med': 0.9977,
#   'pressao_max': 1.0003,
#   'umid_min': 74.5266,
#   'umid_med': 86.6812,
#   'umid_max': 93.734},
#  {'date': '2004-03-03',
#   'geocodigo': 1302603,
#   'temp_min': 24.6572,
#   'temp_med': 26.8089,
#   'temp_max': 30.8657,
#   'precip_min': 0.0256,
#   'precip_med': 0.5198,
#   'precip_max': 1.2996,
#   'precip_tot': 4.1584,
#   'pressao_min': 0.9935,
#   'pressao_med': 0.9973,
#   'pressao_max': 0.9998,
#   'umid_min': 71.6422,
#   'umid_med': 87.1208,
#   'umid_max': 95.1827},
#  {'date': '2004-03-04',
#   'geocodigo': 1302603,
#   'temp_min': 23.6081,
#   'temp_med': 26.188,
#   'temp_max': 30.2358,
#   'precip_min': 0.0368,
#   'precip_med': 1.3554,
#   'precip_max': 4.0796,
#   'precip_tot': 10.8433,
#   'pressao_min': 0.9948,
#   'pressao_med': 0.9975,
#   'pressao_max': 1.0003,
#   'umid_min': 74.7006,
#   'umid_med': 88.4037,
#   'umid_max': 96.4183},
#  {'date': '2004-03-05',
#   'geocodigo': 1302603,
#   'temp_min': 24.4463,
#   'temp_med': 26.3509,
#   'temp_max': 29.2765,
#   'precip_min': 0.0045,
#   'precip_med': 0.2401,
#   'precip_max': 1.5764,
#   'precip_tot': 1.9207,
#   'pressao_min': 0.996,
#   'pressao_med': 0.9982,
#   'pressao_max': 1.001,
#   'umid_min': 71.8122,
#   'umid_med': 86.5412,
#   'umid_max': 94.8557},
#  {'date': '2004-03-06',
#   'geocodigo': 1302603,
#   'temp_min': 23.6015,
#   'temp_med': 25.1991,
#   'temp_max': 27.7875,
#   'precip_min': 0.1878,
#   'precip_med': 1.3736,
#   'precip_max': 3.031,
#   'precip_tot': 10.989,
#   'pressao_min': 0.9973,
#   'pressao_med': 0.9991,
#   'pressao_max': 1.0014,
#   'umid_min': 82.8315,
#   'umid_med': 91.3328,
#   'umid_max': 96.1511},
#  {'date': '2004-03-07',
#   'geocodigo': 1302603,
#   'temp_min': 23.692,
#   'temp_med': 26.2092,
#   'temp_max': 30.1582,
#   'precip_min': 0.0296,
#   'precip_med': 0.3066,
#   'precip_max': 0.9509,
#   'precip_tot': 2.4527,
#   'pressao_min': 0.995,
#   'pressao_med': 0.9987,
#   'pressao_max': 1.001,
#   'umid_min': 75.8704,
#   'umid_med': 86.9306,
#   'umid_max': 95.4182},
#  {'date': '2004-03-08',
#   'geocodigo': 1302603,
#   'temp_min': 24.3737,
#   'temp_med': 25.6639,
#   'temp_max': 27.7902,
#   'precip_min': 0.0919,
#   'precip_med': 1.0674,
#   'precip_max': 2.4132,
#   'precip_tot': 8.5389,
#   'pressao_min': 0.9969,
#   'pressao_med': 0.9991,
#   'pressao_max': 1.0014,
#   'umid_min': 81.9946,
#   'umid_med': 89.7042,
#   'umid_max': 93.6114},
#  {'date': '2004-03-09',
#   'geocodigo': 1302603,
#   'temp_min': 23.6945,
#   'temp_med': 26.4677,
#   'temp_max': 31.498,
#   'precip_min': 0.0229,
#   'precip_med': 0.3039,
#   'precip_max': 1.3695,
#   'precip_tot': 2.4312,
#   'pressao_min': 0.9957,
#   'pressao_med': 0.9989,
#   'pressao_max': 1.0014,
#   'umid_min': 66.1872,
#   'umid_med': 86.4239,
#   'umid_max': 97.1444},
#  {'date': '2004-03-10',
#   'geocodigo': 1302603,
#   'temp_min': 24.1954,
#   'temp_med': 26.8315,
#   'temp_max': 30.0258,
#   'precip_min': 0.0082,
#   'precip_med': 1.2967,
#   'precip_max': 5.8981,
#   'precip_tot': 10.3736,
#   'pressao_min': 0.9954,
#   'pressao_med': 0.9986,
#   'pressao_max': 1.0014,
#   'umid_min': 78.7076,
#   'umid_med': 87.7907,
#   'umid_max': 95.1131},
#  {'date': '2004-03-11',
#   'geocodigo': 1302603,
#   'temp_min': 24.2896,
#   'temp_med': 26.7758,
#   'temp_max': 30.5686,
#   'precip_min': 0.0004,
#   'precip_med': 0.1681,
#   'precip_max': 0.4005,
#   'precip_tot': 1.3446,
#   'pressao_min': 0.9942,
#   'pressao_med': 0.9977,
#   'pressao_max': 0.9998,
#   'umid_min': 71.8121,
#   'umid_med': 87.5955,
#   'umid_max': 94.9823},
#  {'date': '2004-03-12',
#   'geocodigo': 1302603,
#   'temp_min': 24.5293,
#   'temp_med': 26.718,
#   'temp_max': 29.9005,
#   'precip_min': 0.0048,
#   'precip_med': 0.6937,
#   'precip_max': 2.5748,
#   'precip_tot': 5.5496,
#   'pressao_min': 0.9939,
#   'pressao_med': 0.9967,
#   'pressao_max': 0.9994,
#   'umid_min': 73.2739,
#   'umid_med': 88.6993,
#   'umid_max': 96.0458},
#  {'date': '2004-03-13',
#   'geocodigo': 1302603,
#   'temp_min': 24.5558,
#   'temp_med': 25.8159,
#   'temp_max': 27.8324,
#   'precip_min': 0.0004,
#   'precip_med': 1.5967,
#   'precip_max': 4.4656,
#   'precip_tot': 12.7733,
#   'pressao_min': 0.9945,
#   'pressao_med': 0.9969,
#   'pressao_max': 1.0003,
#   'umid_min': 86.1831,
#   'umid_med': 91.0984,
#   'umid_max': 94.3526},
#  {'date': '2004-03-14',
#   'geocodigo': 1302603,
#   'temp_min': 24.5614,
#   'temp_med': 26.6937,
#   'temp_max': 30.2638,
#   'precip_min': 0.0,
#   'precip_med': 0.2254,
#   'precip_max': 0.5911,
#   'precip_tot': 1.8033,
#   'pressao_min': 0.9939,
#   'pressao_med': 0.9976,
#   'pressao_max': 0.9999,
#   'umid_min': 72.8417,
#   'umid_med': 87.4793,
#   'umid_max': 95.9283},
#  {'date': '2004-03-15',
#   'geocodigo': 1302603,
#   'temp_min': 24.3905,
#   'temp_med': 26.7162,
#   'temp_max': 31.4726,
#   'precip_min': 0.0005,
#   'precip_med': 0.5713,
#   'precip_max': 1.9459,
#   'precip_tot': 4.57,
#   'pressao_min': 0.9931,
#   'pressao_med': 0.9969,
#   'pressao_max': 0.9993,
#   'umid_min': 72.1272,
#   'umid_med': 88.0775,
#   'umid_max': 96.655},
#  {'date': '2004-03-16',
#   'geocodigo': 1302603,
#   'temp_min': 24.4908,
#   'temp_med': 26.9047,
#   'temp_max': 30.2823,
#   'precip_min': 0.0,
#   'precip_med': 0.3138,
#   'precip_max': 1.596,
#   'precip_tot': 2.5107,
#   'pressao_min': 0.9933,
#   'pressao_med': 0.9963,
#   'pressao_max': 0.9987,
#   'umid_min': 71.2341,
#   'umid_med': 86.043,
#   'umid_max': 94.8376},
#  {'date': '2004-03-17',
#   'geocodigo': 1302603,
#   'temp_min': 24.7047,
#   'temp_med': 25.8199,
#   'temp_max': 28.0489,
#   'precip_min': 0.021,
#   'precip_med': 0.6798,
#   'precip_max': 3.277,
#   'precip_tot': 5.4382,
#   'pressao_min': 0.9943,
#   'pressao_med': 0.9965,
#   'pressao_max': 0.9991,
#   'umid_min': 83.8069,
#   'umid_med': 90.8419,
#   'umid_max': 95.5333},
#  {'date': '2004-03-18',
#   'geocodigo': 1302603,
#   'temp_min': 24.1725,
#   'temp_med': 26.3684,
#   'temp_max': 29.9553,
#   'precip_min': 0.0055,
#   'precip_med': 0.0683,
#   'precip_max': 0.2439,
#   'precip_tot': 0.5463,
#   'pressao_min': 0.9928,
#   'pressao_med': 0.9957,
#   'pressao_max': 0.9978,
#   'umid_min': 68.8951,
#   'umid_med': 87.529,
#   'umid_max': 95.9741},
#  {'date': '2004-03-19',
#   'geocodigo': 1302603,
#   'temp_min': 24.5024,
#   'temp_med': 26.3933,
#   'temp_max': 29.2796,
#   'precip_min': 0.0,
#   'precip_med': 1.0914,
#   'precip_max': 2.9855,
#   'precip_tot': 8.7314,
#   'pressao_min': 0.9932,
#   'pressao_med': 0.9961,
#   'pressao_max': 0.9989,
#   'umid_min': 78.8428,
#   'umid_med': 89.1237,
#   'umid_max': 94.9343},
#  {'date': '2004-03-20',
#   'geocodigo': 1302603,
#   'temp_min': 24.7919,
#   'temp_med': 26.4743,
#   'temp_max': 28.864,
#   'precip_min': 0.0034,
#   'precip_med': 0.2526,
#   'precip_max': 0.9777,
#   'precip_tot': 2.0208,
#   'pressao_min': 0.9928,
#   'pressao_med': 0.9958,
#   'pressao_max': 0.9982,
#   'umid_min': 80.7321,
#   'umid_med': 89.193,
#   'umid_max': 95.9908},
#  {'date': '2004-03-21',
#   'geocodigo': 1302603,
#   'temp_min': 24.2179,
#   'temp_med': 25.6114,
#   'temp_max': 27.5443,
#   'precip_min': 0.1274,
#   'precip_med': 1.0976,
#   'precip_max': 3.8188,
#   'precip_tot': 8.781,
#   'pressao_min': 0.9935,
#   'pressao_med': 0.9958,
#   'pressao_max': 0.9983,
#   'umid_min': 82.4487,
#   'umid_med': 90.8259,
#   'umid_max': 95.7253},
#  {'date': '2004-03-22',
#   'geocodigo': 1302603,
#   'temp_min': 24.4547,
#   'temp_med': 25.25,
#   'temp_max': 26.1941,
#   'precip_min': 0.3601,
#   'precip_med': 1.194,
#   'precip_max': 2.7426,
#   'precip_tot': 9.5522,
#   'pressao_min': 0.9951,
#   'pressao_med': 0.9968,
#   'pressao_max': 0.9993,
#   'umid_min': 89.0081,
#   'umid_med': 90.8953,
#   'umid_max': 93.1469},
#  {'date': '2004-03-23',
#   'geocodigo': 1302603,
#   'temp_min': 24.1264,
#   'temp_med': 25.6473,
#   'temp_max': 28.2053,
#   'precip_min': 0.0076,
#   'precip_med': 0.3748,
#   'precip_max': 1.2105,
#   'precip_tot': 2.9987,
#   'pressao_min': 0.9952,
#   'pressao_med': 0.9977,
#   'pressao_max': 1.0002,
#   'umid_min': 84.7274,
#   'umid_med': 92.0738,
#   'umid_max': 97.171},
#  {'date': '2004-03-24',
#   'geocodigo': 1302603,
#   'temp_min': 24.3262,
#   'temp_med': 26.4309,
#   'temp_max': 29.15,
#   'precip_min': 0.0174,
#   'precip_med': 0.3729,
#   'precip_max': 2.3944,
#   'precip_tot': 2.9835,
#   'pressao_min': 0.9942,
#   'pressao_med': 0.9974,
#   'pressao_max': 0.9993,
#   'umid_min': 75.3518,
#   'umid_med': 88.2155,
#   'umid_max': 97.0715},
#  {'date': '2004-03-25',
#   'geocodigo': 1302603,
#   'temp_min': 24.2629,
#   'temp_med': 25.6217,
#   'temp_max': 27.5126,
#   'precip_min': 0.2457,
#   'precip_med': 0.7279,
#   'precip_max': 1.4298,
#   'precip_tot': 5.8232,
#   'pressao_min': 0.9939,
#   'pressao_med': 0.9965,
#   'pressao_max': 0.999,
#   'umid_min': 85.2883,
#   'umid_med': 91.5485,
#   'umid_max': 96.4358},
#  {'date': '2004-03-26',
#   'geocodigo': 1302603,
#   'temp_min': 24.3329,
#   'temp_med': 25.7968,
#   'temp_max': 28.1644,
#   'precip_min': 0.4346,
#   'precip_med': 1.163,
#   'precip_max': 2.234,
#   'precip_tot': 9.3043,
#   'pressao_min': 0.9927,
#   'pressao_med': 0.996,
#   'pressao_max': 0.9986,
#   'umid_min': 84.9147,
#   'umid_med': 92.313,
#   'umid_max': 97.2088},
#  {'date': '2004-03-27',
#   'geocodigo': 1302603,
#   'temp_min': 24.1943,
#   'temp_med': 24.6917,
#   'temp_max': 25.5655,
#   'precip_min': 0.6782,
#   'precip_med': 3.0017,
#   'precip_max': 8.6988,
#   'precip_tot': 24.0135,
#   'pressao_min': 0.994,
#   'pressao_med': 0.9958,
#   'pressao_max': 0.9981,
#   'umid_min': 89.7503,
#   'umid_med': 93.1322,
#   'umid_max': 95.6862},
#  {'date': '2004-03-28',
#   'geocodigo': 1302603,
#   'temp_min': 23.7751,
#   'temp_med': 25.6337,
#   'temp_max': 28.8814,
#   'precip_min': 0.2473,
#   'precip_med': 0.7967,
#   'precip_max': 2.0784,
#   'precip_tot': 6.3738,
#   'pressao_min': 0.993,
#   'pressao_med': 0.9962,
#   'pressao_max': 0.999,
#   'umid_min': 79.2827,
#   'umid_med': 90.1265,
#   'umid_max': 97.5736},
#  {'date': '2004-03-29',
#   'geocodigo': 1302603,
#   'temp_min': 23.727,
#   'temp_med': 26.5215,
#   'temp_max': 30.7733,
#   'precip_min': 0.0004,
#   'precip_med': 0.0687,
#   'precip_max': 0.1845,
#   'precip_tot': 0.5494,
#   'pressao_min': 0.9942,
#   'pressao_med': 0.997,
#   'pressao_max': 1.0001,
#   'umid_min': 69.9707,
#   'umid_med': 85.1121,
#   'umid_max': 96.3783},
#  {'date': '2004-03-30',
#   'geocodigo': 1302603,
#   'temp_min': 25.1763,
#   'temp_med': 26.349,
#   'temp_max': 27.9488,
#   'precip_min': 0.0113,
#   'precip_med': 0.4823,
#   'precip_max': 2.2068,
#   'precip_tot': 3.8584,
#   'pressao_min': 0.9962,
#   'pressao_med': 0.9988,
#   'pressao_max': 1.0018,
#   'umid_min': 86.1656,
#   'umid_med': 89.5173,
#   'umid_max': 94.4859},
#  {'date': '2004-03-31',
#   'geocodigo': 1302603,
#   'temp_min': 24.3802,
#   'temp_med': 26.5014,
#   'temp_max': 30.3781,
#   'precip_min': 0.058,
#   'precip_med': 0.3395,
#   'precip_max': 0.625,
#   'precip_tot': 2.7158,
#   'pressao_min': 0.9957,
#   'pressao_med': 0.9992,
#   'pressao_max': 1.0013,
#   'umid_min': 75.1822,
#   'umid_med': 90.1008,
#   'umid_max': 98.5999},
#  {'date': '2004-04-01',
#   'geocodigo': 1302603,
#   'temp_min': 24.0192,
#   'temp_med': 27.6648,
#   'temp_max': 32.7171,
#   'precip_min': 0.0,
#   'precip_med': 0.1208,
#   'precip_max': 0.6445,
#   'precip_tot': 0.9668,
#   'pressao_min': 0.9941,
#   'pressao_med': 0.9973,
#   'pressao_max': 0.9996,
#   'umid_min': 64.3825,
#   'umid_med': 84.2821,
#   'umid_max': 97.8675},
#  {'date': '2004-04-02',
#   'geocodigo': 1302603,
#   'temp_min': 24.5858,
#   'temp_med': 27.4951,
#   'temp_max': 30.8188,
#   'precip_min': 0.0004,
#   'precip_med': 0.1204,
#   'precip_max': 0.5457,
#   'precip_tot': 0.9628,
#   'pressao_min': 0.995,
#   'pressao_med': 0.997,
#   'pressao_max': 0.9993,
#   'umid_min': 68.524,
#   'umid_med': 85.9477,
#   'umid_max': 95.3598},
#  {'date': '2004-04-03',
#   'geocodigo': 1302603,
#   'temp_min': 24.6033,
#   'temp_med': 27.1853,
#   'temp_max': 30.9043,
#   'precip_min': 0.0,
#   'precip_med': 0.1887,
#   'precip_max': 1.1571,
#   'precip_tot': 1.5095,
#   'pressao_min': 0.994,
#   'pressao_med': 0.9968,
#   'pressao_max': 0.9991,
#   'umid_min': 75.7344,
#   'umid_med': 86.9873,
#   'umid_max': 93.7873},
#  {'date': '2004-04-04',
#   'geocodigo': 1302603,
#   'temp_min': 24.3053,
#   'temp_med': 26.2484,
#   'temp_max': 28.5996,
#   'precip_min': 0.0005,
#   'precip_med': 0.826,
#   'precip_max': 2.9307,
#   'precip_tot': 6.6081,
#   'pressao_min': 0.9954,
#   'pressao_med': 0.9975,
#   'pressao_max': 1.0003,
#   'umid_min': 84.0411,
#   'umid_med': 90.8322,
#   'umid_max': 95.3848},
#  {'date': '2004-04-05',
#   'geocodigo': 1302603,
#   'temp_min': 25.052,
#   'temp_med': 27.3124,
#   'temp_max': 30.7274,
#   'precip_min': 0.0,
#   'precip_med': 0.6932,
#   'precip_max': 5.2348,
#   'precip_tot': 5.5456,
#   'pressao_min': 0.9954,
#   'pressao_med': 0.9982,
#   'pressao_max': 1.001,
#   'umid_min': 71.9819,
#   'umid_med': 86.9517,
#   'umid_max': 97.6871},
#  {'date': '2004-04-06',
#   'geocodigo': 1302603,
#   'temp_min': 24.9109,
#   'temp_med': 26.7614,
#   'temp_max': 29.1466,
#   'precip_min': 0.0,
#   'precip_med': 0.3172,
#   'precip_max': 1.2505,
#   'precip_tot': 2.5377,
#   'pressao_min': 0.9955,
#   'pressao_med': 0.9978,
#   'pressao_max': 1.0004,
#   'umid_min': 69.4021,
#   'umid_med': 87.7352,
#   'umid_max': 97.3287},
#  {'date': '2004-04-07',
#   'geocodigo': 1302603,
#   'temp_min': 23.9626,
#   'temp_med': 26.865,
#   'temp_max': 31.6691,
#   'precip_min': 0.0,
#   'precip_med': 0.0796,
#   'precip_max': 0.3549,
#   'precip_tot': 0.637,
#   'pressao_min': 0.9938,
#   'pressao_med': 0.9966,
#   'pressao_max': 0.9997,
#   'umid_min': 68.8179,
#   'umid_med': 86.6699,
#   'umid_max': 97.7186},
#  {'date': '2004-04-08',
#   'geocodigo': 1302603,
#   'temp_min': 25.1479,
#   'temp_med': 27.843,
#   'temp_max': 31.5567,
#   'precip_min': 0.0,
#   'precip_med': 0.066,
#   'precip_max': 0.195,
#   'precip_tot': 0.5278,
#   'pressao_min': 0.9933,
#   'pressao_med': 0.9967,
#   'pressao_max': 0.999,
#   'umid_min': 73.383,
#   'umid_med': 85.3406,
#   'umid_max': 95.6174},
#  {'date': '2004-04-09',
#   'geocodigo': 1302603,
#   'temp_min': 24.9949,
#   'temp_med': 27.7597,
#   'temp_max': 31.3882,
#   'precip_min': 0.0,
#   'precip_med': 0.3854,
#   'precip_max': 2.5823,
#   'precip_tot': 3.083,
#   'pressao_min': 0.9931,
#   'pressao_med': 0.9965,
#   'pressao_max': 0.9998,
#   'umid_min': 68.4146,
#   'umid_med': 84.4045,
#   'umid_max': 93.6541}]

# %%
df = pd.DataFrame(items)
df
# Out:
#           date  geocodigo  temp_min  temp_med  temp_max  precip_min  \
# 0   2004-01-01    1302603   24.7052   26.7748   30.5519      0.0000
# 1   2004-01-02    1302603   24.5850   26.8201   30.1501      0.0212
# 2   2004-01-03    1302603   24.2967   26.2160   28.7951      0.0028
# 3   2004-01-04    1302603   24.4803   26.0561   28.5809      0.0006
# 4   2004-01-05    1302603   24.1931   25.6888   28.6974      0.0647
# ..         ...        ...       ...       ...       ...         ...
# 95  2004-04-05    1302603   25.0520   27.3124   30.7274      0.0000
# 96  2004-04-06    1302603   24.9109   26.7614   29.1466      0.0000
# 97  2004-04-07    1302603   23.9626   26.8650   31.6691      0.0000
# 98  2004-04-08    1302603   25.1479   27.8430   31.5567      0.0000
# 99  2004-04-09    1302603   24.9949   27.7597   31.3882      0.0000
#
#     precip_med  precip_max  precip_tot  pressao_min  pressao_med  pressao_max  \
# 0       0.7406      3.0196      5.9251       0.9951       0.9980       1.0012
# 1       0.7749      3.4790      6.1993       0.9937       0.9971       0.9990
# 2       0.5410      1.0341      4.3277       0.9933       0.9962       0.9981
# 3       0.3706      1.8163      2.9649       0.9925       0.9951       0.9970
# 4       0.8415      2.1096      6.7318       0.9938       0.9955       0.9973
# ..         ...         ...         ...          ...          ...          ...
# 95      0.6932      5.2348      5.5456       0.9954       0.9982       1.0010
# 96      0.3172      1.2505      2.5377       0.9955       0.9978       1.0004
# 97      0.0796      0.3549      0.6370       0.9938       0.9966       0.9997
# 98      0.0660      0.1950      0.5278       0.9933       0.9967       0.9990
# 99      0.3854      2.5823      3.0830       0.9931       0.9965       0.9998
#
#     umid_min  umid_med  umid_max
# 0    75.0331   87.1228   94.9243
# 1    74.2346   86.2345   95.9302
# 2    80.7129   89.0086   93.7411
# 3    76.6341   88.7608   94.3893
# 4    80.7770   90.8974   94.9595
# ..       ...       ...       ...
# 95   71.9819   86.9517   97.6871
# 96   69.4021   87.7352   97.3287
# 97   68.8179   86.6699   97.7186
# 98   73.3830   85.3406   95.6174
# 99   68.4146   84.4045   93.6541
#
# [100 rows x 15 columns]

# %%
pages = np.arange(1, 19) # total amount of pages is returned in the request
per_page = 100
for page in pages:
    pagination = f"?page={page}&per_page={per_page}&"
    filters = "start=%s&end=%s" % ("2004-01-01", "2008-12-31")

    resp = requests.get(climate_api + pagination + filters)

# Or you can add a geocode to the filters
geocode = 1302603
resp = requests.get(
    climate_api + 
    pagination + 
    filters +
    f"&geocode={geocode}"
)

items = resp.json()["items"] # JSON data in dict format
#total_items = resp.json()["total_items"] # JSON data in dict format
resp.json()["pagination"] # Pagination*
# Out:
# {'items': 6,
#  'total_items': 1706,
#  'page': 18,
#  'total_pages': 18,
#  'per_page': 100}

# %%
items
# Out:
# [{'date': '2008-12-26',
#   'geocodigo': 1302603,
#   'temp_min': 23.9931,
#   'temp_med': 26.339,
#   'temp_max': 30.0015,
#   'precip_min': 0.0101,
#   'precip_med': 0.0573,
#   'precip_max': 0.1243,
#   'precip_tot': 0.4584,
#   'pressao_min': 0.9909,
#   'pressao_med': 0.9945,
#   'pressao_max': 0.9965,
#   'umid_min': 67.8897,
#   'umid_med': 85.8279,
#   'umid_max': 95.0748},
#  {'date': '2008-12-27',
#   'geocodigo': 1302603,
#   'temp_min': 24.2679,
#   'temp_med': 25.8514,
#   'temp_max': 28.0496,
#   'precip_min': 0.1398,
#   'precip_med': 0.7252,
#   'precip_max': 3.4506,
#   'precip_tot': 5.8018,
#   'pressao_min': 0.992,
#   'pressao_med': 0.9947,
#   'pressao_max': 0.9974,
#   'umid_min': 77.0052,
#   'umid_med': 88.3014,
#   'umid_max': 94.0025},
#  {'date': '2008-12-28',
#   'geocodigo': 1302603,
#   'temp_min': 24.4061,
#   'temp_med': 26.4017,
#   'temp_max': 29.3633,
#   'precip_min': 0.0103,
#   'precip_med': 0.8356,
#   'precip_max': 3.8776,
#   'precip_tot': 6.6847,
#   'pressao_min': 0.9933,
#   'pressao_med': 0.9952,
#   'pressao_max': 0.9975,
#   'umid_min': 75.8251,
#   'umid_med': 88.0135,
#   'umid_max': 94.8036},
#  {'date': '2008-12-29',
#   'geocodigo': 1302603,
#   'temp_min': 24.1979,
#   'temp_med': 26.7066,
#   'temp_max': 31.0737,
#   'precip_min': 0.0353,
#   'precip_med': 0.4734,
#   'precip_max': 1.2593,
#   'precip_tot': 3.7872,
#   'pressao_min': 0.9917,
#   'pressao_med': 0.9953,
#   'pressao_max': 0.9977,
#   'umid_min': 70.3917,
#   'umid_med': 86.7352,
#   'umid_max': 94.0349},
#  {'date': '2008-12-30',
#   'geocodigo': 1302603,
#   'temp_min': 23.807,
#   'temp_med': 24.7968,
#   'temp_max': 26.8158,
#   'precip_min': 0.4586,
#   'precip_med': 6.8408,
#   'precip_max': 23.2136,
#   'precip_tot': 54.7267,
#   'pressao_min': 0.9943,
#   'pressao_med': 0.9959,
#   'pressao_max': 0.9984,
#   'umid_min': 86.4121,
#   'umid_med': 91.593,
#   'umid_max': 94.2908},
#  {'date': '2008-12-31',
#   'geocodigo': 1302603,
#   'temp_min': 23.0573,
#   'temp_med': 25.0496,
#   'temp_max': 28.3984,
#   'precip_min': 0.0108,
#   'precip_med': 1.8999,
#   'precip_max': 5.5882,
#   'precip_tot': 15.1989,
#   'pressao_min': 0.9944,
#   'pressao_med': 0.9964,
#   'pressao_max': 0.9991,
#   'umid_min': 74.3636,
#   'umid_med': 88.609,
#   'umid_max': 95.6304}]

# %%
per_page = 100
total_pages = 18 
start_date = "2004-01-01"
end_date = "2008-12-31"
geocode = 1302603

all_items = []  # List to store all items

# Loop through each page
for page in range(1, total_pages + 1):
    pagination = f"?page={page}&per_page={per_page}&"
    filters = f"start={start_date}&end={end_date}&geocode={geocode}"
    
    resp = requests.get(climate_api + pagination + filters)
    
    # Check if the request was successful
    if resp.status_code == 200:
        items = resp.json().get("items", [])  # Get items, default to an empty list if key not found
        all_items.extend(items)  # Append the items from this page to the list
    else:
        print(f"Failed to retrieve data for page {page}")
        break  # Break the loop in case of a failed request

df = pd.DataFrame(all_items)
df
# Out:
#             date  geocodigo  temp_min  temp_med  temp_max  precip_min  \
# 0     2004-01-01    1302603   24.7052   26.7748   30.5519      0.0000
# 1     2004-01-02    1302603   24.5850   26.8201   30.1501      0.0212
# 2     2004-01-03    1302603   24.2967   26.2160   28.7951      0.0028
# 3     2004-01-04    1302603   24.4803   26.0561   28.5809      0.0006
# 4     2004-01-05    1302603   24.1931   25.6888   28.6974      0.0647
# ...          ...        ...       ...       ...       ...         ...
# 1701  2008-12-27    1302603   24.2679   25.8514   28.0496      0.1398
# 1702  2008-12-28    1302603   24.4061   26.4017   29.3633      0.0103
# 1703  2008-12-29    1302603   24.1979   26.7066   31.0737      0.0353
# 1704  2008-12-30    1302603   23.8070   24.7968   26.8158      0.4586
# 1705  2008-12-31    1302603   23.0573   25.0496   28.3984      0.0108
#
#       precip_med  precip_max  precip_tot  pressao_min  pressao_med  \
# 0         0.7406      3.0196      5.9251       0.9951       0.9980
# 1         0.7749      3.4790      6.1993       0.9937       0.9971
# 2         0.5410      1.0341      4.3277       0.9933       0.9962
# 3         0.3706      1.8163      2.9649       0.9925       0.9951
# 4         0.8415      2.1096      6.7318       0.9938       0.9955
# ...          ...         ...         ...          ...          ...
# 1701      0.7252      3.4506      5.8018       0.9920       0.9947
# 1702      0.8356      3.8776      6.6847       0.9933       0.9952
# 1703      0.4734      1.2593      3.7872       0.9917       0.9953
# 1704      6.8408     23.2136     54.7267       0.9943       0.9959
# 1705      1.8999      5.5882     15.1989       0.9944       0.9964
#
#       pressao_max  umid_min  umid_med  umid_max
# 0          1.0012   75.0331   87.1228   94.9243
# 1          0.9990   74.2346   86.2345   95.9302
# 2          0.9981   80.7129   89.0086   93.7411
# 3          0.9970   76.6341   88.7608   94.3893
# 4          0.9973   80.7770   90.8974   94.9595
# ...           ...       ...       ...       ...
# 1701       0.9974   77.0052   88.3014   94.0025
# 1702       0.9975   75.8251   88.0135   94.8036
# 1703       0.9977   70.3917   86.7352   94.0349
# 1704       0.9984   86.4121   91.5930   94.2908
# 1705       0.9991   74.3636   88.6090   95.6304
#
# [1706 rows x 15 columns]

# %%
def split_dataframe(df):
    chunks = []
    start = 0
    # First chunk with 366 rows
    chunks.append(df.iloc[start:start + 366])
    start += 366
    
    # Remaining chunks with 365 rows each
    while start < len(df):
        chunks.append(df.iloc[start:start + 365])
        start += 365
        
    return chunks

# Split the DataFrame
df_chunks = split_dataframe(df)

# Example to print the number of rows in each chunk
for i, chunk in enumerate(df_chunks):
    print(f"Chunk {i+1} has {len(chunk)} rows")
# Out:
# Chunk 1 has 366 rows
# Chunk 2 has 365 rows
# Chunk 3 has 365 rows
# Chunk 4 has 365 rows
# Chunk 5 has 245 rows

# %%
datetime_df = pd.DataFrame()
datetime_df['date'] = pd.to_datetime(df['date'])

# Extract the year from the 'date' column
datetime_df['year'] = datetime_df['date'].dt.year

# Count the occurrences of each year
year_counts = datetime_df['year'].value_counts().sort_index()

print(year_counts)
# Out:
# 2004    335
# 2005    275
# 2006    365
# 2007    365
# 2008    366
# Name: year, dtype: int64

# %%
datetime_df
# Out:
#            date  year
# 0    2004-01-01  2004
# 1    2004-01-02  2004
# 2    2004-01-03  2004
# 3    2004-01-04  2004
# 4    2004-01-05  2004
# ...         ...   ...
# 1701 2008-12-27  2008
# 1702 2008-12-28  2008
# 1703 2008-12-29  2008
# 1704 2008-12-30  2008
# 1705 2008-12-31  2008
#
# [1706 rows x 2 columns]

# %%
#df

# %%
specific_year = 2005

# Ensure 'date' column is in datetime format
datetime_df['date'] = pd.to_datetime(datetime_df['date'])

# Filter the DataFrame for the specific year
df_year = datetime_df[datetime_df['date'].dt.year == specific_year]

# Extract the month from the 'date' column
df_year['month'] = df_year['date'].dt.month

# Count the occurrences of each month
month_counts = df_year['month'].value_counts().sort_index()

print(month_counts)
# Out:
# 3     31
# 4     30
# 6     30
# 7     31
# 8     31
# 9     30
# 10    31
# 11    30
# 12    31
# Name: month, dtype: int64
# <ipython-input-15-614954a5c235>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_year['month'] = df_year['date'].dt.month

# %%
df.get('date').iloc[0]
# Out:
# '2004-01-01'

# %%
df['date']
# Out:
# 0       2004-01-01
# 1       2004-01-02
# 2       2004-01-03
# 3       2004-01-04
# 4       2004-01-05
#            ...
# 1701    2008-12-27
# 1702    2008-12-28
# 1703    2008-12-29
# 1704    2008-12-30
# 1705    2008-12-31
# Name: date, Length: 1706, dtype: object

# %%
df[df.get('date')=='2005-01-01']
# Out:
# Empty DataFrame
# Columns: [date, geocodigo, temp_min, temp_med, temp_max, precip_min, precip_med, precip_max, precip_tot, pressao_min, pressao_med, pressao_max, umid_min, umid_med, umid_max]
# Index: []

# %%
df[df.get('date')=='2005-03-01']
# Out:
#            date  geocodigo  temp_min  temp_med  temp_max  precip_min  \
# 335  2005-03-01    1302603   24.9851   26.2156   27.7896      0.0003
#
#      precip_med  precip_max  precip_tot  pressao_min  pressao_med  \
# 335      0.9978      3.4509      7.9821       0.9956       0.9979
#
#      pressao_max  umid_min  umid_med  umid_max
# 335       1.0012   88.6641   92.8638   96.6048

# %%
df[df.get('date')=='2005-05-01']
# Out:
# Empty DataFrame
# Columns: [date, geocodigo, temp_min, temp_med, temp_max, precip_min, precip_med, precip_max, precip_tot, pressao_min, pressao_med, pressao_max, umid_min, umid_med, umid_max]
# Index: []
